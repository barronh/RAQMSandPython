# %%
from IPython.core.display import HTML
HTML("""<style>
.answers { 
    visibility: hidden;
}
</style>""")
# Out:
# <style>
# .answers {
#     visibility: hidden;
# }
# </style>

# %%
from notebook.services.config import ConfigManager
icm = ConfigManager()
icm.update('livereveal', {
              'theme': 'simple',
              'transition': 'convex',
              'start_slideshow_at': 'selected'
});

# %% [markdown]
# # Python Common Data Model
# Presented by: Barron H. Henderson, Byeong-Uk Kim

# %% [markdown]
# # Loading Plotting and Science Libaries

# %%
# Prepare my slides
# %pylab inline
# %cd working
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/barronh/Development/RAQMSandPython/working

# %% [markdown]
# # Downloads DC3 Observations
#
# In this exercise, we will use publicly available data as a playground for learning about the Common Data Model and how to use it in Python. Download Merged Observations from Deep Clouds, Convection, and Chemistry (DC3) data from the DC8 aircraft during the DC3 campaign.
#
# In a minute, not yet, we are going to download the data.

# %%
# %mkdir icartt
# Out:
# mkdir: cannot create directory ‘icartt’: File exists

# %%
from urllib.request import urlretrieve
url='http://www-air.larc.nasa.gov/cgi-bin/enzFile?e38EE03EFAE02C04F06E9647DAF98F48D6A2f7075622d6169722f534541433452532d4443332f4d45524745532f315f4d494e5554452e4443385f4d52472f6463332d6d726736302d6463385f6d657267655f32303132303531385f52375f7468727532303132303632322e696374'
dc3path = 'icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict'
import os
if not os.path.exists(dc3path):
    urlretrieve(url, filename = dc3path);

# %% [markdown]
# # Download CMAQ Benchmark
#
# Benchmark data is available from CMAS's website. We're only using 1 day, so we won't download the whole thing.

# %% [markdown]
# # Downloading just what we need

# %%
from urllib.request import urlretrieve, url2pathname
import os
ftproot = 'ftp://data.as.essie.ufl.edu/pub/exch/CMAQandPython/'
aconcpath = ftproot +\
            'cmaq/CCTM_D502a_Linux2_x86_64intel.ACONC.GA12C_20060801.nc4'
metcro3dpath = ftproot +\
            'cmaq/METCRO3D_Benchmark.nc4'
urlpaths = [aconcpath, metcro3dpath]
for urlpath in urlpaths:
    local_filename = os.path.join('cmaq', os.path.basename(urlpath))
    if not os.path.exists(local_filename):
        urlretrieve(urlpath, filename = local_filename)

# %% [markdown]
# # CHECK POINT:
# List the size of of the file you downloaded

# %%
import os
aconcpath = 'cmaq/CCTM_D502a_Linux2_x86_64intel.ACONC.GA12C_20060801.nc4'
metcro3dpath = 'cmaq/METCRO3D_Benchmark.nc4'
dc3path = 'icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict'
for path in [aconcpath, metcro3dpath, dc3path]:
    print('%5.1fM' % (os.path.getsize(path)/1024.**2), path)
# Out:
# 253.5M cmaq/CCTM_D502a_Linux2_x86_64intel.ACONC.GA12C_20060801.nc4
#  51.7M cmaq/METCRO3D_Benchmark.nc4
#  30.6M icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict

# %% [markdown]
# # ANSWERS Hidden
#
# <div class="answers">
# ```
# 253.5M cmaq/CCTM_D502a_Linux2_x86_64intel.ACONC.GA12C_20060801.nc4
#  51.7M cmaq/METCRO3D_Benchmark.nc4
#  30.6M icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict
# ```
# </div>

# %% [markdown]
# # Intro to the Common Data Model
#
# 1. files and groups
# 2. dimensions
# 3. properties
# 4. variables
# 5. Conventions
#   * IOAPI and WRF-IOAPI
#   * COARDS
#   * Climate Forecasting (CF) Conventions
# 6. Conceptualizing any data set as CDM

# %% [markdown]
# # NetCDF and PseudoNetCDF
#
# - NetCDF is a library (and was a format) that utilizes the CDM
# - NetCDF-Java extended the CDM to other formats in Java
# - PseudoNetCDF extends the idea to atmospheric data of many formats in Python
#
# (I/O API is a library and meta-data convention and library)

# %% [markdown]
# # [P]NC Tools
#
# PseudoNetCDF has pncdump.py, pncgen.py, pncmap.py, and many more utilities that can be used from the command line or from within Python. These give a Common Data Model interface to many formats.
#
# The Common Data Model is most useful when dimensions can be directly translated to physical time and space. pnc tools, like CDO, help by creating a common internal standard meta-data. This allows for space/time aware processing.

# %%
# Import PseudoNetCDF Processor (PNC)
from PseudoNetCDF import PNC
help(PNC)
# Out:
# Help on function PNC in module PseudoNetCDF.pncparse:
#
# PNC(*args, ifiles=[], actions=None, **kwds)
#     Arguments:
#         args - Command Line arguments/options for PseudoNetCDF
#                for full list of potential args PNC('--help')
#         ifiles - (optional) pre-loaded input files
#         actions -  (default: False)
#             False: only open files do not make outputs
#             True: enable dump,gen,map,etc output actions
#                   for action options see subparsers help
#                   e.g., PNC('dump', '--help', actions = True)
#
#     Returns:
#         out - Namespace object with parsed arguments
#               including a list of processed files (out.ifiles)
#
#     Example:
#         # Single File
#         out = PNC('--format=netcdf', inpath)
#         infile = out.ifiles[0]
#         O3 = infile.variables['O3']
#
#         # Multiple Files
#         out = PNC('--format=netcdf', inpath1, inpath2)
#         infile1, infile2 = out.ifiles
#         O3_1 = infile1.variables['O3']
#         O3_2 = infile2.variables['O3']
#
#         # With Actions
#         out = PNC('dump', '--variables=O3', '--format=netcdf', inpath)
#     PseudoNetCDF.icarttfiles.ffi1001.ffi1001 icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict {
#     dimensions:
#             POINTS = 6817 ;
#
#     variables:
#             double O3(TSTEP, LAY, ROW, COL);
#                     O3_ESRL:units = "ppbV" ;
#                     O3_ESRL:standard_name = "Ozone" ;
#                     O3_ESRL:missing_value = -999999 ;
#         ...

# %% [markdown]
# # Check Point
#
# - List 5 formats that PNC tools can read.
# - How do you reduce the time dimension using the `mean` function?
# - How do you get the 3rd element of the latitude dimension?

# %% [markdown]
# # Answers Hidden
#
# <div class="answers">
# ```
# PNC('--list-formats')
# ```
# Example answer:
# - netcdf (e.g., CMAQ, WRF, new GEOS-Chem, etc)
# - geoschemfiles.bpch (aka bpch)
# - icarttfiles.ffi1001.ffi1001 (aka ffi1001)
# - camxfiles.uamiv.Memmap.temperature (aka uamiv)
# - textfiles.csv
# - camxfiles.temperature.Memmap.temperature (aka temperature)
# - camxfiles.point_source.Memmap.point_source (aka point_source)
#
# ```
# PNC('--help')
# ```
#
#     -s dim,start[,stop[,step]], --slice dim,start[,stop[,step]]
#                         Variables have dimensions (time, layer, lat, lon),
#                         which can be subset using dim,start,stop,stride (e.g.,
#                         --slice=layer,0,47,5 would sample every fifth layer
#                         starting at 0)
#     -r dim,function[,weight], --reduce dim,function[,weight]
#                         Variable dimensions can be reduced using
#                         dim,function,weight syntax (e.g.,
#                         --reduce=layer,mean,weight). Weighting is not fully
#                         functional.
#
# PNC('--reduce=time,mean', '--slice=latitude,2')
# </div>

# %% [markdown]
# # Example DC3
#
# Explore the Common Data Language, which describes the Common Data Model, using the `dump` action.
# The dump action has the same general functionality of the ncdump NetCDF utility. Use the `dump`
# action to display the CDL for the dc3path.
#
# ```
# dc3args = PNC('dump', '--header',
#               '--format=ffi1001', dc3path,
#               actions = True)
# ```

# %%
dc3args = PNC('dump', '--header',
              '--format=ffi1001', dc3path,
              actions = True);
# Out:
# PseudoNetCDF.icarttfiles.ffi1001.ffi1001 icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict {
# dimensions:
#         POINTS = 6817 ;
#
# variables:
#         double Fractional_Day(POINTS);
#                 Fractional_Day:units = "Fractional_Day, none" ;
#                 Fractional_Day:standard_name = "Fractional_Day" ;
#                 Fractional_Day:missing_value = -999999 ;
#                 Fractional_Day:fill_value = -999999.0 ;
#                 Fractional_Day:scale = 1.0 ;
#                 Fractional_Day:llod_flag = -888888 ;
#                 Fractional_Day:llod_value = "N/A" ;
#                 Fractional_Day:ulod_flag = -777777 ;
#                 Fractional_Day:ulod_value = "N/A" ;
#         double UTC(POINTS);
#                 UTC:units = "s" ;
#                 UTC:standard_name = "UTC" ;
#                 UTC:missing_value = -999999 ;
#                 UTC:fill_value = -999999.0 ;
#                 UTC:scale = 1 ;
#                 UTC:llod_flag = -888888 ;
#                 UTC:llod_value = "N/A" ;
#                 UTC:ulod_flag = -777777 ;
#                 UTC:ulod_value = "N/A" ;
#         double JDAY(POINTS);
#                 JDAY:units = "days" ;
#                 JDAY:standard_name = "JDAY" ;
#                 JDAY:missing_value = -999999 ;
#                 JDAY:fill_value = -999999.0 ;
#                 JDAY:scale = 1 ;
#                 JDAY:llod_flag = -888888 ;
#                 JDAY:llod_value = "N/A" ;
#                 JDAY:ulod_flag = -777777 ;
#                 JDAY:ulod_value = "N/A" ;
#         double INDEX(POINTS);
#                 INDEX:units = "none" ;
#                 INDEX:standard_name = "INDEX" ;
#                 INDEX:missing_value = -999999 ;
#                 INDEX:fill_value = -999999.0 ;
#                 INDEX:scale = 1 ;
#                 INDEX:llod_flag = -888888 ;
#                 INDEX:llod_value = "N/A" ;
#                 INDEX:ulod_flag = -777777 ;
#                 INDEX:ulod_value = "N/A" ;
#         double FLIGHT(POINTS);
#                 FLIGHT:units = "none" ;
#                 FLIGHT:standard_name = "FLIGHT" ;
#                 FLIGHT:missing_value = -999999 ;
#                 FLIGHT:fill_value = -999999.0 ;
#                 FLIGHT:scale = 1 ;
#                 FLIGHT:llod_flag = -888888 ;
#                 FLIGHT:llod_value = "N/A" ;
#                 FLIGHT:ulod_flag = -777777 ;
#                 FLIGHT:ulod_value = "N/A" ;
#         double LOCAL_SUN_TIME(POINTS);
#                 LOCAL_SUN_TIME:units = "hour" ;
#                 LOCAL_SUN_TIME:standard_name = "LOCAL_SUN_TIME" ;
#                 LOCAL_SUN_TIME:missing_value = -999999 ;
#                 LOCAL_SUN_TIME:fill_value = -999999.0 ;
#                 LOCAL_SUN_TIME:scale = 1 ;
#                 LOCAL_SUN_TIME:llod_flag = -888888 ;
#                 LOCAL_SUN_TIME:llod_value = "N/A" ;
#                 LOCAL_SUN_TIME:ulod_flag = -777777 ;
#                 LOCAL_SUN_TIME:ulod_value = "N/A" ;
#         double LATITUDE(POINTS);
#                 LATITUDE:units = "degs" ;
#                 LATITUDE:standard_name = "LATITUDE" ;
#                 LATITUDE:missing_value = -999999 ;
#                 LATITUDE:fill_value = -999999.0 ;
#                 LATITUDE:scale = 1 ;
#                 LATITUDE:llod_flag = -888888 ;
#                 LATITUDE:llod_value = "N/A" ;
#                 LATITUDE:ulod_flag = -777777 ;
#                 LATITUDE:ulod_value = "N/A" ;
#         double LONGITUDE(POINTS);
#                 LONGITUDE:units = "degs" ;
#                 LONGITUDE:standard_name = "LONGITUDE" ;
#                 LONGITUDE:missing_value = -999999 ;
#                 LONGITUDE:fill_value = -999999.0 ;
#                 LONGITUDE:scale = 1 ;
#                 LONGITUDE:llod_flag = -888888 ;
#                 LONGITUDE:llod_value = "N/A" ;
#                 LONGITUDE:ulod_flag = -777777 ;
#                 LONGITUDE:ulod_value = "N/A" ;
#         double ALTP(POINTS);
#                 ALTP:units = "km" ;
#                 ALTP:standard_name = "ALTP" ;
#                 ALTP:missing_value = -999999 ;
#                 ALTP:fill_value = -999999.0 ;
#                 ALTP:scale = 1 ;
#                 ALTP:llod_flag = -888888 ;
#                 ALTP:llod_value = "N/A" ;
#                 ALTP:ulod_flag = -777777 ;
#                 ALTP:ulod_value = "N/A" ;
#         double PRESSURE(POINTS);
#                 PRESSURE:units = "hPa" ;
#                 PRESSURE:standard_name = "PRESSURE" ;
#                 PRESSURE:missing_value = -999999 ;
#                 PRESSURE:fill_value = -999999.0 ;
#                 PRESSURE:scale = 1 ;
#                 PRESSURE:llod_flag = -888888 ;
#                 PRESSURE:llod_value = "N/A" ;
#                 PRESSURE:ulod_flag = -777777 ;
#                 PRESSURE:ulod_value = "N/A" ;
#         double TEMPERATURE(POINTS);
#                 TEMPERATURE:units = "K" ;
#                 TEMPERATURE:standard_name = "TEMPERATURE" ;
#                 TEMPERATURE:missing_value = -999999 ;
#                 TEMPERATURE:fill_value = -999999.0 ;
#                 TEMPERATURE:scale = 1 ;
#                 TEMPERATURE:llod_flag = -888888 ;
#                 TEMPERATURE:llod_value = "N/A" ;
#                 TEMPERATURE:ulod_flag = -777777 ;
#                 TEMPERATURE:ulod_value = "N/A" ;
#         double THETA(POINTS);
#                 THETA:units = "K" ;
#                 THETA:standard_name = "THETA" ;
#                 THETA:missing_value = -999999 ;
#                 THETA:fill_value = -999999.0 ;
#                 THETA:scale = 1 ;
#                 THETA:llod_flag = -888888 ;
#                 THETA:llod_value = "N/A" ;
#                 THETA:ulod_flag = -777777 ;
#                 THETA:ulod_value = "N/A" ;
#         double O3COLUMN(POINTS);
#                 O3COLUMN:units = "DU" ;
#                 O3COLUMN:standard_name = "O3COLUMN" ;
#                 O3COLUMN:missing_value = -999999 ;
#                 O3COLUMN:fill_value = -999999.0 ;
#                 O3COLUMN:scale = 1 ;
#                 O3COLUMN:llod_flag = -888888 ;
#                 O3COLUMN:llod_value = "N/A" ;
#                 O3COLUMN:ulod_flag = -777777 ;
#                 O3COLUMN:ulod_value = "N/A" ;
#         double SZA(POINTS);
#                 SZA:units = "deg" ;
#                 SZA:standard_name = "SZA" ;
#                 SZA:missing_value = -999999 ;
#                 SZA:fill_value = -999999.0 ;
#                 SZA:scale = 1 ;
#                 SZA:llod_flag = -888888 ;
#                 SZA:llod_value = "N/A" ;
#                 SZA:ulod_flag = -777777 ;
#                 SZA:ulod_value = "N/A" ;
#         double WNS(POINTS);
#                 WNS:units = "m s-1" ;
#                 WNS:standard_name = "WNS" ;
#                 WNS:missing_value = -999999 ;
#                 WNS:fill_value = -999999.0 ;
#                 WNS:scale = 1 ;
#                 WNS:llod_flag = -888888 ;
#                 WNS:llod_value = "N/A" ;
#                 WNS:ulod_flag = -777777 ;
#                 WNS:ulod_value = "N/A" ;
#         double WND(POINTS);
#                 WND:units = "Degs" ;
#                 WND:standard_name = "WND" ;
#                 WND:missing_value = -999999 ;
#                 WND:fill_value = -999999.0 ;
#                 WND:scale = 1 ;
#                 WND:llod_flag = -888888 ;
#                 WND:llod_value = "N/A" ;
#                 WND:ulod_flag = -777777 ;
#                 WND:ulod_value = "N/A" ;
#         double GPS_ALT(POINTS);
#                 GPS_ALT:units = "km" ;
#                 GPS_ALT:standard_name = "GPS_ALT" ;
#                 GPS_ALT:missing_value = -999999 ;
#                 GPS_ALT:fill_value = -999999.0 ;
#                 GPS_ALT:scale = 1 ;
#                 GPS_ALT:llod_flag = -888888 ;
#                 GPS_ALT:llod_value = "N/A" ;
#                 GPS_ALT:ulod_flag = -777777 ;
#                 GPS_ALT:ulod_value = "N/A" ;
#         double RadarAlt(POINTS);
#                 RadarAlt:units = "km" ;
#                 RadarAlt:standard_name = "RadarAlt" ;
#                 RadarAlt:missing_value = -999999 ;
#                 RadarAlt:fill_value = -999999.0 ;
#                 RadarAlt:scale = 1 ;
#                 RadarAlt:llod_flag = -888888 ;
#                 RadarAlt:llod_value = "N/A" ;
#                 RadarAlt:ulod_flag = -777777 ;
#                 RadarAlt:ulod_value = "N/A" ;
#         double GRD_SPD(POINTS);
#                 GRD_SPD:units = "m s-1" ;
#                 GRD_SPD:standard_name = "GRD_SPD" ;
#                 GRD_SPD:missing_value = -999999 ;
#                 GRD_SPD:fill_value = -999999.0 ;
#                 GRD_SPD:scale = 1 ;
#                 GRD_SPD:llod_flag = -888888 ;
#                 GRD_SPD:llod_value = "N/A" ;
#                 GRD_SPD:ulod_flag = -777777 ;
#                 GRD_SPD:ulod_value = "N/A" ;
#         double TAS(POINTS);
#                 TAS:units = "m s-1" ;
#                 TAS:standard_name = "TAS" ;
#                 TAS:missing_value = -999999 ;
#                 TAS:fill_value = -999999.0 ;
#                 TAS:scale = 1 ;
#                 TAS:llod_flag = -888888 ;
#                 TAS:llod_value = "N/A" ;
#                 TAS:ulod_flag = -777777 ;
#                 TAS:ulod_value = "N/A" ;
#         double IAS(POINTS);
#                 IAS:units = "m/s" ;
#                 IAS:standard_name = "IAS" ;
#                 IAS:missing_value = -999999 ;
#                 IAS:fill_value = -999999.0 ;
#                 IAS:scale = 1 ;
#                 IAS:llod_flag = -888888 ;
#                 IAS:llod_value = "N/A" ;
#                 IAS:ulod_flag = -777777 ;
#                 IAS:ulod_value = "N/A" ;
#         double MachNumber(POINTS);
#                 MachNumber:units = "mach" ;
#                 MachNumber:standard_name = "MachNumber" ;
#                 MachNumber:missing_value = -999999 ;
#                 MachNumber:fill_value = -999999.0 ;
#                 MachNumber:scale = 1 ;
#                 MachNumber:llod_flag = -888888 ;
#                 MachNumber:llod_value = "N/A" ;
#                 MachNumber:ulod_flag = -777777 ;
#                 MachNumber:ulod_value = "N/A" ;
#         double VerticalSpeed(POINTS);
#                 VerticalSpeed:units = "m s-1" ;
#                 VerticalSpeed:standard_name = "VerticalSpeed" ;
#                 VerticalSpeed:missing_value = -999999 ;
#                 VerticalSpeed:fill_value = -999999.0 ;
#                 VerticalSpeed:scale = 1 ;
#                 VerticalSpeed:llod_flag = -888888 ;
#                 VerticalSpeed:llod_value = "N/A" ;
#                 VerticalSpeed:ulod_flag = -777777 ;
#                 VerticalSpeed:ulod_value = "N/A" ;
#         double HDG(POINTS);
#                 HDG:units = "degs" ;
#                 HDG:standard_name = "HDG" ;
#                 HDG:missing_value = -999999 ;
#                 HDG:fill_value = -999999.0 ;
#                 HDG:scale = 1 ;
#                 HDG:llod_flag = -888888 ;
#                 HDG:llod_value = "N/A" ;
#                 HDG:ulod_flag = -777777 ;
#                 HDG:ulod_value = "N/A" ;
#         double TRK(POINTS);
#                 TRK:units = "degs" ;
#                 TRK:standard_name = "TRK" ;
#                 TRK:missing_value = -999999 ;
#                 TRK:fill_value = -999999.0 ;
#                 TRK:scale = 1 ;
#                 TRK:llod_flag = -888888 ;
#                 TRK:llod_value = "N/A" ;
#                 TRK:ulod_flag = -777777 ;
#                 TRK:ulod_value = "N/A" ;
#         double DriftAngle(POINTS);
#                 DriftAngle:units = "degs" ;
#                 DriftAngle:standard_name = "DriftAngle" ;
#                 DriftAngle:missing_value = -999999 ;
#                 DriftAngle:fill_value = -999999.0 ;
#                 DriftAngle:scale = 1 ;
#                 DriftAngle:llod_flag = -888888 ;
#                 DriftAngle:llod_value = "N/A" ;
#                 DriftAngle:ulod_flag = -777777 ;
#                 DriftAngle:ulod_value = "N/A" ;
#         double PITCH(POINTS);
#                 PITCH:units = "degs" ;
#                 PITCH:standard_name = "PITCH" ;
#                 PITCH:missing_value = -999999 ;
#                 PITCH:fill_value = -999999.0 ;
#                 PITCH:scale = 1 ;
#                 PITCH:llod_flag = -888888 ;
#                 PITCH:llod_value = "N/A" ;
#                 PITCH:ulod_flag = -777777 ;
#                 PITCH:ulod_value = "N/A" ;
#         double ROLL(POINTS);
#                 ROLL:units = "degs" ;
#                 ROLL:standard_name = "ROLL" ;
#                 ROLL:missing_value = -999999 ;
#                 ROLL:fill_value = -999999.0 ;
#                 ROLL:scale = 1 ;
#                 ROLL:llod_flag = -888888 ;
#                 ROLL:llod_value = "N/A" ;
#                 ROLL:ulod_flag = -777777 ;
#                 ROLL:ulod_value = "N/A" ;
#         double Dewpoint(POINTS);
#                 Dewpoint:units = "K" ;
#                 Dewpoint:standard_name = "Dewpoint" ;
#                 Dewpoint:missing_value = -999999 ;
#                 Dewpoint:fill_value = -999999.0 ;
#                 Dewpoint:scale = 1 ;
#                 Dewpoint:llod_flag = -888888 ;
#                 Dewpoint:llod_value = "N/A" ;
#                 Dewpoint:ulod_flag = -777777 ;
#                 Dewpoint:ulod_value = "N/A" ;
#         double TotalTemp_Aircraft(POINTS);
#                 TotalTemp_Aircraft:units = "K" ;
#                 TotalTemp_Aircraft:standard_name = "TotalTemp_Aircraft" ;
#                 TotalTemp_Aircraft:missing_value = -999999 ;
#                 TotalTemp_Aircraft:fill_value = -999999.0 ;
#                 TotalTemp_Aircraft:scale = 1 ;
#                 TotalTemp_Aircraft:llod_flag = -888888 ;
#                 TotalTemp_Aircraft:llod_value = "N/A" ;
#                 TotalTemp_Aircraft:ulod_flag = -777777 ;
#                 TotalTemp_Aircraft:ulod_value = "N/A" ;
#         double IR_SurfTemp(POINTS);
#                 IR_SurfTemp:units = "K" ;
#                 IR_SurfTemp:standard_name = "IR_SurfTemp" ;
#                 IR_SurfTemp:missing_value = -999999 ;
#                 IR_SurfTemp:fill_value = -999999.0 ;
#                 IR_SurfTemp:scale = 1 ;
#                 IR_SurfTemp:llod_flag = -888888 ;
#                 IR_SurfTemp:llod_value = "N/A" ;
#                 IR_SurfTemp:ulod_flag = -777777 ;
#                 IR_SurfTemp:ulod_value = "N/A" ;
#         double CabinPressure(POINTS);
#                 CabinPressure:units = "hPa" ;
#                 CabinPressure:standard_name = "CabinPressure" ;
#                 CabinPressure:missing_value = -999999 ;
#                 CabinPressure:fill_value = -999999.0 ;
#                 CabinPressure:scale = 1 ;
#                 CabinPressure:llod_flag = -888888 ;
#                 CabinPressure:llod_value = "N/A" ;
#                 CabinPressure:ulod_flag = -777777 ;
#                 CabinPressure:ulod_value = "N/A" ;
#         double SolarZenithAngle(POINTS);
#                 SolarZenithAngle:units = "degs" ;
#                 SolarZenithAngle:standard_name = "SolarZenithAngle" ;
#                 SolarZenithAngle:missing_value = -999999 ;
#                 SolarZenithAngle:fill_value = -999999.0 ;
#                 SolarZenithAngle:scale = 1 ;
#                 SolarZenithAngle:llod_flag = -888888 ;
#                 SolarZenithAngle:llod_value = "N/A" ;
#                 SolarZenithAngle:ulod_flag = -777777 ;
#                 SolarZenithAngle:ulod_value = "N/A" ;
#         double AircraftSunElevation(POINTS);
#                 AircraftSunElevation:units = "degs" ;
#                 AircraftSunElevation:standard_name = "AircraftSunElevation" ;
#                 AircraftSunElevation:missing_value = -999999 ;
#                 AircraftSunElevation:fill_value = -999999.0 ;
#                 AircraftSunElevation:scale = 1 ;
#                 AircraftSunElevation:llod_flag = -888888 ;
#                 AircraftSunElevation:llod_value = "N/A" ;
#                 AircraftSunElevation:ulod_flag = -777777 ;
#                 AircraftSunElevation:ulod_value = "N/A" ;
#         double SunAzimuth(POINTS);
#                 SunAzimuth:units = "degs" ;
#                 SunAzimuth:standard_name = "SunAzimuth" ;
#                 SunAzimuth:missing_value = -999999 ;
#                 SunAzimuth:fill_value = -999999.0 ;
#                 SunAzimuth:scale = 1 ;
#                 SunAzimuth:llod_flag = -888888 ;
#                 SunAzimuth:llod_value = "N/A" ;
#                 SunAzimuth:ulod_flag = -777777 ;
#                 SunAzimuth:ulod_value = "N/A" ;
#         double AircraftSunAzimuth(POINTS);
#                 AircraftSunAzimuth:units = "degs" ;
#                 AircraftSunAzimuth:standard_name = "AircraftSunAzimuth" ;
#                 AircraftSunAzimuth:missing_value = -999999 ;
#                 AircraftSunAzimuth:fill_value = -999999.0 ;
#                 AircraftSunAzimuth:scale = 1 ;
#                 AircraftSunAzimuth:llod_flag = -888888 ;
#                 AircraftSunAzimuth:llod_value = "N/A" ;
#                 AircraftSunAzimuth:ulod_flag = -777777 ;
#                 AircraftSunAzimuth:ulod_value = "N/A" ;
#         double MixingRatio(POINTS);
#                 MixingRatio:units = "g kg-1" ;
#                 MixingRatio:standard_name = "MixingRatio" ;
#                 MixingRatio:missing_value = -999999 ;
#                 MixingRatio:fill_value = -999999.0 ;
#                 MixingRatio:scale = 1 ;
#                 MixingRatio:llod_flag = -888888 ;
#                 MixingRatio:llod_value = "N/A" ;
#                 MixingRatio:ulod_flag = -777777 ;
#                 MixingRatio:ulod_value = "N/A" ;
#         double VaporPresWater(POINTS);
#                 VaporPresWater:units = "hPa" ;
#                 VaporPresWater:standard_name = "VaporPresWater" ;
#                 VaporPresWater:missing_value = -999999 ;
#                 VaporPresWater:fill_value = -999999.0 ;
#                 VaporPresWater:scale = 1 ;
#                 VaporPresWater:llod_flag = -888888 ;
#                 VaporPresWater:llod_value = "N/A" ;
#                 VaporPresWater:ulod_flag = -777777 ;
#                 VaporPresWater:ulod_value = "N/A" ;
#         double SatVaporPresWater(POINTS);
#                 SatVaporPresWater:units = "hPa" ;
#                 SatVaporPresWater:standard_name = "SatVaporPresWater" ;
#                 SatVaporPresWater:missing_value = -999999 ;
#                 SatVaporPresWater:fill_value = -999999.0 ;
#                 SatVaporPresWater:scale = 1 ;
#                 SatVaporPresWater:llod_flag = -888888 ;
#                 SatVaporPresWater:llod_value = "N/A" ;
#                 SatVaporPresWater:ulod_flag = -777777 ;
#                 SatVaporPresWater:ulod_value = "N/A" ;
#         double SatVaporPresIce(POINTS);
#                 SatVaporPresIce:units = "hPa" ;
#                 SatVaporPresIce:standard_name = "SatVaporPresIce" ;
#                 SatVaporPresIce:missing_value = -999999 ;
#                 SatVaporPresIce:fill_value = -999999.0 ;
#                 SatVaporPresIce:scale = 1 ;
#                 SatVaporPresIce:llod_flag = -888888 ;
#                 SatVaporPresIce:llod_value = "N/A" ;
#                 SatVaporPresIce:ulod_flag = -777777 ;
#                 SatVaporPresIce:ulod_value = "N/A" ;
#         double RelativeHumidity(POINTS);
#                 RelativeHumidity:units = "%" ;
#                 RelativeHumidity:standard_name = "RelativeHumidity" ;
#                 RelativeHumidity:missing_value = -999999 ;
#                 RelativeHumidity:fill_value = -999999.0 ;
#                 RelativeHumidity:scale = 1 ;
#                 RelativeHumidity:llod_flag = -888888 ;
#                 RelativeHumidity:llod_value = "N/A" ;
#                 RelativeHumidity:ulod_flag = -777777 ;
#                 RelativeHumidity:ulod_value = "N/A" ;
#         double StaticPressure_MMS(POINTS);
#                 StaticPressure_MMS:units = "hPa" ;
#                 StaticPressure_MMS:standard_name = "StaticPressure_MMS" ;
#                 StaticPressure_MMS:missing_value = -999999 ;
#                 StaticPressure_MMS:fill_value = -999999.0 ;
#                 StaticPressure_MMS:scale = 1 ;
#                 StaticPressure_MMS:llod_flag = -888888 ;
#                 StaticPressure_MMS:llod_value = "N/A" ;
#                 StaticPressure_MMS:ulod_flag = -777777 ;
#                 StaticPressure_MMS:ulod_value = "N/A" ;
#         double StaticTemp_MMS(POINTS);
#                 StaticTemp_MMS:units = "K" ;
#                 StaticTemp_MMS:standard_name = "StaticTemp_MMS" ;
#                 StaticTemp_MMS:missing_value = -999999 ;
#                 StaticTemp_MMS:fill_value = -999999.0 ;
#                 StaticTemp_MMS:scale = 1 ;
#                 StaticTemp_MMS:llod_flag = -888888 ;
#                 StaticTemp_MMS:llod_value = "N/A" ;
#                 StaticTemp_MMS:ulod_flag = -777777 ;
#                 StaticTemp_MMS:ulod_value = "N/A" ;
#         double TAS_MMS(POINTS);
#                 TAS_MMS:units = "m s-1" ;
#                 TAS_MMS:standard_name = "TAS_MMS" ;
#                 TAS_MMS:missing_value = -999999 ;
#                 TAS_MMS:fill_value = -999999.0 ;
#                 TAS_MMS:scale = 1 ;
#                 TAS_MMS:llod_flag = -888888 ;
#                 TAS_MMS:llod_value = "N/A" ;
#                 TAS_MMS:ulod_flag = -777777 ;
#                 TAS_MMS:ulod_value = "N/A" ;
#         double U_MMS(POINTS);
#                 U_MMS:units = "m s-1" ;
#                 U_MMS:standard_name = "U_MMS" ;
#                 U_MMS:missing_value = -999999 ;
#                 U_MMS:fill_value = -999999.0 ;
#                 U_MMS:scale = 1 ;
#                 U_MMS:llod_flag = -888888 ;
#                 U_MMS:llod_value = "N/A" ;
#                 U_MMS:ulod_flag = -777777 ;
#                 U_MMS:ulod_value = "N/A" ;
#         double V_MMS(POINTS);
#                 V_MMS:units = "m s-1" ;
#                 V_MMS:standard_name = "V_MMS" ;
#                 V_MMS:missing_value = -999999 ;
#                 V_MMS:fill_value = -999999.0 ;
#                 V_MMS:scale = 1 ;
#                 V_MMS:llod_flag = -888888 ;
#                 V_MMS:llod_value = "N/A" ;
#                 V_MMS:ulod_flag = -777777 ;
#                 V_MMS:ulod_value = "N/A" ;
#         double W_MMS(POINTS);
#                 W_MMS:units = "m s-1" ;
#                 W_MMS:standard_name = "W_MMS" ;
#                 W_MMS:missing_value = -999999 ;
#                 W_MMS:fill_value = -999999.0 ;
#                 W_MMS:scale = 1 ;
#                 W_MMS:llod_flag = -888888 ;
#                 W_MMS:llod_value = "N/A" ;
#                 W_MMS:ulod_flag = -777777 ;
#                 W_MMS:ulod_value = "N/A" ;
#         double TurbDissipationRate_MMS(POINTS);
#                 TurbDissipationRate_MMS:units = "kW kg-1" ;
#                 TurbDissipationRate_MMS:standard_name = "TurbDissipationRate_MMS" ;
#                 TurbDissipationRate_MMS:missing_value = -999999 ;
#                 TurbDissipationRate_MMS:fill_value = -999999.0 ;
#                 TurbDissipationRate_MMS:scale = 1 ;
#                 TurbDissipationRate_MMS:llod_flag = -888888 ;
#                 TurbDissipationRate_MMS:llod_value = "N/A" ;
#                 TurbDissipationRate_MMS:ulod_flag = -777777 ;
#                 TurbDissipationRate_MMS:ulod_value = "N/A" ;
#         double ReynoldsNumber_MMS(POINTS);
#                 ReynoldsNumber_MMS:units = "m-1" ;
#                 ReynoldsNumber_MMS:standard_name = "ReynoldsNumber_MMS" ;
#                 ReynoldsNumber_MMS:missing_value = -999999 ;
#                 ReynoldsNumber_MMS:fill_value = -999999.0 ;
#                 ReynoldsNumber_MMS:scale = 1 ;
#                 ReynoldsNumber_MMS:llod_flag = -888888 ;
#                 ReynoldsNumber_MMS:llod_value = "N/A" ;
#                 ReynoldsNumber_MMS:ulod_flag = -777777 ;
#                 ReynoldsNumber_MMS:ulod_value = "N/A" ;
#         double GPS_LAT_MMS(POINTS);
#                 GPS_LAT_MMS:units = "degs" ;
#                 GPS_LAT_MMS:standard_name = "GPS_LAT_MMS" ;
#                 GPS_LAT_MMS:missing_value = -999999 ;
#                 GPS_LAT_MMS:fill_value = -999999.0 ;
#                 GPS_LAT_MMS:scale = 1 ;
#                 GPS_LAT_MMS:llod_flag = -888888 ;
#                 GPS_LAT_MMS:llod_value = "N/A" ;
#                 GPS_LAT_MMS:ulod_flag = -777777 ;
#                 GPS_LAT_MMS:ulod_value = "N/A" ;
#         double GPS_LON_MMS(POINTS);
#                 GPS_LON_MMS:units = "degs" ;
#                 GPS_LON_MMS:standard_name = "GPS_LON_MMS" ;
#                 GPS_LON_MMS:missing_value = -999999 ;
#                 GPS_LON_MMS:fill_value = -999999.0 ;
#                 GPS_LON_MMS:scale = 1 ;
#                 GPS_LON_MMS:llod_flag = -888888 ;
#                 GPS_LON_MMS:llod_value = "N/A" ;
#                 GPS_LON_MMS:ulod_flag = -777777 ;
#                 GPS_LON_MMS:ulod_value = "N/A" ;
#         double GPS_ALT_MMS(POINTS);
#                 GPS_ALT_MMS:units = "km" ;
#                 GPS_ALT_MMS:standard_name = "GPS_ALT_MMS" ;
#                 GPS_ALT_MMS:missing_value = -999999 ;
#                 GPS_ALT_MMS:fill_value = -999999.0 ;
#                 GPS_ALT_MMS:scale = 1 ;
#                 GPS_ALT_MMS:llod_flag = -888888 ;
#                 GPS_ALT_MMS:llod_value = "N/A" ;
#                 GPS_ALT_MMS:ulod_flag = -777777 ;
#                 GPS_ALT_MMS:ulod_value = "N/A" ;
#         double THETA_MMS(POINTS);
#                 THETA_MMS:units = "K" ;
#                 THETA_MMS:standard_name = "THETA_MMS" ;
#                 THETA_MMS:missing_value = -999999 ;
#                 THETA_MMS:fill_value = -999999.0 ;
#                 THETA_MMS:scale = 1 ;
#                 THETA_MMS:llod_flag = -888888 ;
#                 THETA_MMS:llod_value = "N/A" ;
#                 THETA_MMS:ulod_flag = -777777 ;
#                 THETA_MMS:ulod_value = "N/A" ;
#         double ROLL_MMS(POINTS);
#                 ROLL_MMS:units = "degs" ;
#                 ROLL_MMS:standard_name = "ROLL_MMS" ;
#                 ROLL_MMS:missing_value = -999999 ;
#                 ROLL_MMS:fill_value = -999999.0 ;
#                 ROLL_MMS:scale = 1 ;
#                 ROLL_MMS:llod_flag = -888888 ;
#                 ROLL_MMS:llod_value = "N/A" ;
#                 ROLL_MMS:ulod_flag = -777777 ;
#                 ROLL_MMS:ulod_value = "N/A" ;
#         double HDG_MMS(POINTS);
#                 HDG_MMS:units = "degs" ;
#                 HDG_MMS:standard_name = "HDG_MMS" ;
#                 HDG_MMS:missing_value = -999999 ;
#                 HDG_MMS:fill_value = -999999.0 ;
#                 HDG_MMS:scale = 1 ;
#                 HDG_MMS:llod_flag = -888888 ;
#                 HDG_MMS:llod_value = "N/A" ;
#                 HDG_MMS:ulod_flag = -777777 ;
#                 HDG_MMS:ulod_value = "N/A" ;
#         double PITCH_MMS(POINTS);
#                 PITCH_MMS:units = "degs" ;
#                 PITCH_MMS:standard_name = "PITCH_MMS" ;
#                 PITCH_MMS:missing_value = -999999 ;
#                 PITCH_MMS:fill_value = -999999.0 ;
#                 PITCH_MMS:scale = 1 ;
#                 PITCH_MMS:llod_flag = -888888 ;
#                 PITCH_MMS:llod_value = "N/A" ;
#                 PITCH_MMS:ulod_flag = -777777 ;
#                 PITCH_MMS:ulod_value = "N/A" ;
#         double GFS_TROP_HGT(POINTS);
#                 GFS_TROP_HGT:units = "km" ;
#                 GFS_TROP_HGT:standard_name = "GFS_TROP_HGT" ;
#                 GFS_TROP_HGT:missing_value = -999999 ;
#                 GFS_TROP_HGT:fill_value = -999999.0 ;
#                 GFS_TROP_HGT:scale = 1 ;
#                 GFS_TROP_HGT:llod_flag = -888888 ;
#                 GFS_TROP_HGT:llod_value = "N/A" ;
#                 GFS_TROP_HGT:ulod_flag = -777777 ;
#                 GFS_TROP_HGT:ulod_value = "N/A" ;
#         double GFS_TROP_PRESS(POINTS);
#                 GFS_TROP_PRESS:units = "hPa" ;
#                 GFS_TROP_PRESS:standard_name = "GFS_TROP_PRESS" ;
#                 GFS_TROP_PRESS:missing_value = -999999 ;
#                 GFS_TROP_PRESS:fill_value = -999999.0 ;
#                 GFS_TROP_PRESS:scale = 1 ;
#                 GFS_TROP_PRESS:llod_flag = -888888 ;
#                 GFS_TROP_PRESS:llod_value = "N/A" ;
#                 GFS_TROP_PRESS:ulod_flag = -777777 ;
#                 GFS_TROP_PRESS:ulod_value = "N/A" ;
#         double GFS_TROP_TEMP(POINTS);
#                 GFS_TROP_TEMP:units = "K" ;
#                 GFS_TROP_TEMP:standard_name = "GFS_TROP_TEMP" ;
#                 GFS_TROP_TEMP:missing_value = -999999 ;
#                 GFS_TROP_TEMP:fill_value = -999999.0 ;
#                 GFS_TROP_TEMP:scale = 1 ;
#                 GFS_TROP_TEMP:llod_flag = -888888 ;
#                 GFS_TROP_TEMP:llod_value = "N/A" ;
#                 GFS_TROP_TEMP:ulod_flag = -777777 ;
#                 GFS_TROP_TEMP:ulod_value = "N/A" ;
#         double GFS_2PVU_HGT(POINTS);
#                 GFS_2PVU_HGT:units = "km" ;
#                 GFS_2PVU_HGT:standard_name = "GFS_2PVU_HGT" ;
#                 GFS_2PVU_HGT:missing_value = -999999 ;
#                 GFS_2PVU_HGT:fill_value = -999999.0 ;
#                 GFS_2PVU_HGT:scale = 1 ;
#                 GFS_2PVU_HGT:llod_flag = -888888 ;
#                 GFS_2PVU_HGT:llod_value = "N/A" ;
#                 GFS_2PVU_HGT:ulod_flag = -777777 ;
#                 GFS_2PVU_HGT:ulod_value = "N/A" ;
#         double GFS_2PVU_PRESS(POINTS);
#                 GFS_2PVU_PRESS:units = "hPa" ;
#                 GFS_2PVU_PRESS:standard_name = "GFS_2PVU_PRESS" ;
#                 GFS_2PVU_PRESS:missing_value = -999999 ;
#                 GFS_2PVU_PRESS:fill_value = -999999.0 ;
#                 GFS_2PVU_PRESS:scale = 1 ;
#                 GFS_2PVU_PRESS:llod_flag = -888888 ;
#                 GFS_2PVU_PRESS:llod_value = "N/A" ;
#                 GFS_2PVU_PRESS:ulod_flag = -777777 ;
#                 GFS_2PVU_PRESS:ulod_value = "N/A" ;
#         double GFS_2PVU_TEMP(POINTS);
#                 GFS_2PVU_TEMP:units = "K" ;
#                 GFS_2PVU_TEMP:standard_name = "GFS_2PVU_TEMP" ;
#                 GFS_2PVU_TEMP:missing_value = -999999 ;
#                 GFS_2PVU_TEMP:fill_value = -999999.0 ;
#                 GFS_2PVU_TEMP:scale = 1 ;
#                 GFS_2PVU_TEMP:llod_flag = -888888 ;
#                 GFS_2PVU_TEMP:llod_value = "N/A" ;
#                 GFS_2PVU_TEMP:ulod_flag = -777777 ;
#                 GFS_2PVU_TEMP:ulod_value = "N/A" ;
#         double CO2_MixingRatio(POINTS);
#                 CO2_MixingRatio:units = "ppmv" ;
#                 CO2_MixingRatio:standard_name = "CO2_MixingRatio" ;
#                 CO2_MixingRatio:missing_value = -999999 ;
#                 CO2_MixingRatio:fill_value = -999999.0 ;
#                 CO2_MixingRatio:scale = 1 ;
#                 CO2_MixingRatio:llod_flag = -888888 ;
#                 CO2_MixingRatio:llod_value = "N/A" ;
#                 CO2_MixingRatio:ulod_flag = -777777 ;
#                 CO2_MixingRatio:ulod_value = "N/A" ;
#         double CO_DACOM(POINTS);
#                 CO_DACOM:units = "ppbv" ;
#                 CO_DACOM:standard_name = "CO_DACOM" ;
#                 CO_DACOM:missing_value = -999999 ;
#                 CO_DACOM:fill_value = -999999.0 ;
#                 CO_DACOM:scale = 1 ;
#                 CO_DACOM:llod_flag = -888888 ;
#                 CO_DACOM:llod_value = "N/A" ;
#                 CO_DACOM:ulod_flag = -777777 ;
#                 CO_DACOM:ulod_value = "N/A" ;
#         double CH4_DACOM(POINTS);
#                 CH4_DACOM:units = "ppbv" ;
#                 CH4_DACOM:standard_name = "CH4_DACOM" ;
#                 CH4_DACOM:missing_value = -999999 ;
#                 CH4_DACOM:fill_value = -999999.0 ;
#                 CH4_DACOM:scale = 1 ;
#                 CH4_DACOM:llod_flag = -888888 ;
#                 CH4_DACOM:llod_value = "N/A" ;
#                 CH4_DACOM:ulod_flag = -777777 ;
#                 CH4_DACOM:ulod_value = "N/A" ;
#         double N2O_DACOM(POINTS);
#                 N2O_DACOM:units = "ppbv" ;
#                 N2O_DACOM:standard_name = "N2O_DACOM" ;
#                 N2O_DACOM:missing_value = -999999 ;
#                 N2O_DACOM:fill_value = -999999.0 ;
#                 N2O_DACOM:scale = 1 ;
#                 N2O_DACOM:llod_flag = -888888 ;
#                 N2O_DACOM:llod_value = "N/A" ;
#                 N2O_DACOM:ulod_flag = -777777 ;
#                 N2O_DACOM:ulod_value = "N/A" ;
#         double H2O_vapor_DLH(POINTS);
#                 H2O_vapor_DLH:units = "ppmv" ;
#                 H2O_vapor_DLH:standard_name = "H2O_vapor_DLH" ;
#                 H2O_vapor_DLH:missing_value = -999999 ;
#                 H2O_vapor_DLH:fill_value = -999999.0 ;
#                 H2O_vapor_DLH:scale = 1 ;
#                 H2O_vapor_DLH:llod_flag = -888888 ;
#                 H2O_vapor_DLH:llod_value = "N/A" ;
#                 H2O_vapor_DLH:ulod_flag = -777777 ;
#                 H2O_vapor_DLH:ulod_value = "N/A" ;
#         double CH2O_LIF(POINTS);
#                 CH2O_LIF:units = "pptv" ;
#                 CH2O_LIF:standard_name = "CH2O_LIF" ;
#                 CH2O_LIF:missing_value = -999999 ;
#                 CH2O_LIF:fill_value = -999999.0 ;
#                 CH2O_LIF:scale = 1 ;
#                 CH2O_LIF:llod_flag = -888888 ;
#                 CH2O_LIF:llod_value = "N/A" ;
#                 CH2O_LIF:ulod_flag = -777777 ;
#                 CH2O_LIF:ulod_value = "N/A" ;
#         double CH2O_DFGAS(POINTS);
#                 CH2O_DFGAS:units = "pptv" ;
#                 CH2O_DFGAS:standard_name = "CH2O_DFGAS" ;
#                 CH2O_DFGAS:missing_value = -999999 ;
#                 CH2O_DFGAS:fill_value = -999999.0 ;
#                 CH2O_DFGAS:scale = 1 ;
#                 CH2O_DFGAS:llod_flag = -888888 ;
#                 CH2O_DFGAS:llod_value = "N/A" ;
#                 CH2O_DFGAS:ulod_flag = -777777 ;
#                 CH2O_DFGAS:ulod_value = "N/A" ;
#         double NO2_ESRL(POINTS);
#                 NO2_ESRL:units = "ppbv" ;
#                 NO2_ESRL:standard_name = "NO2_ESRL" ;
#                 NO2_ESRL:missing_value = -999999 ;
#                 NO2_ESRL:fill_value = -999999.0 ;
#                 NO2_ESRL:scale = 1 ;
#                 NO2_ESRL:llod_flag = -888888 ;
#                 NO2_ESRL:llod_value = "N/A" ;
#                 NO2_ESRL:ulod_flag = -777777 ;
#                 NO2_ESRL:ulod_value = "N/A" ;
#         double NOy_ESRL(POINTS);
#                 NOy_ESRL:units = "ppbv" ;
#                 NOy_ESRL:standard_name = "NOy_ESRL" ;
#                 NOy_ESRL:missing_value = -999999 ;
#                 NOy_ESRL:fill_value = -999999.0 ;
#                 NOy_ESRL:scale = 1 ;
#                 NOy_ESRL:llod_flag = -888888 ;
#                 NOy_ESRL:llod_value = "N/A" ;
#                 NOy_ESRL:ulod_flag = -777777 ;
#                 NOy_ESRL:ulod_value = "N/A" ;
#         double NO_ESRL(POINTS);
#                 NO_ESRL:units = "ppbv" ;
#                 NO_ESRL:standard_name = "NO_ESRL" ;
#                 NO_ESRL:missing_value = -999999 ;
#                 NO_ESRL:fill_value = -999999.0 ;
#                 NO_ESRL:scale = 1 ;
#                 NO_ESRL:llod_flag = -888888 ;
#                 NO_ESRL:llod_value = "N/A" ;
#                 NO_ESRL:ulod_flag = -777777 ;
#                 NO_ESRL:ulod_value = "N/A" ;
#         double O3_ESRL(POINTS);
#                 O3_ESRL:units = "ppbv" ;
#                 O3_ESRL:standard_name = "O3_ESRL" ;
#                 O3_ESRL:missing_value = -999999 ;
#                 O3_ESRL:fill_value = -999999.0 ;
#                 O3_ESRL:scale = 1 ;
#                 O3_ESRL:llod_flag = -888888 ;
#                 O3_ESRL:llod_value = "N/A" ;
#                 O3_ESRL:ulod_flag = -777777 ;
#                 O3_ESRL:ulod_value = "N/A" ;
#         double NO2_TDLIF(POINTS);
#                 NO2_TDLIF:units = "pptv" ;
#                 NO2_TDLIF:standard_name = "NO2_TDLIF" ;
#                 NO2_TDLIF:missing_value = -999999 ;
#                 NO2_TDLIF:fill_value = -999999.0 ;
#                 NO2_TDLIF:scale = 1 ;
#                 NO2_TDLIF:llod_flag = -888888 ;
#                 NO2_TDLIF:llod_value = "N/A" ;
#                 NO2_TDLIF:ulod_flag = -777777 ;
#                 NO2_TDLIF:ulod_value = "N/A" ;
#         double MPN_TDLIF(POINTS);
#                 MPN_TDLIF:units = "pptv" ;
#                 MPN_TDLIF:standard_name = "MPN_TDLIF" ;
#                 MPN_TDLIF:missing_value = -999999 ;
#                 MPN_TDLIF:fill_value = -999999.0 ;
#                 MPN_TDLIF:scale = 1 ;
#                 MPN_TDLIF:llod_flag = -888888 ;
#                 MPN_TDLIF:llod_value = "N/A" ;
#                 MPN_TDLIF:ulod_flag = -777777 ;
#                 MPN_TDLIF:ulod_value = "N/A" ;
#         double PNs_TDLIF(POINTS);
#                 PNs_TDLIF:units = "pptv" ;
#                 PNs_TDLIF:standard_name = "PNs_TDLIF" ;
#                 PNs_TDLIF:missing_value = -999999 ;
#                 PNs_TDLIF:fill_value = -999999.0 ;
#                 PNs_TDLIF:scale = 1 ;
#                 PNs_TDLIF:llod_flag = -888888 ;
#                 PNs_TDLIF:llod_value = "N/A" ;
#                 PNs_TDLIF:ulod_flag = -777777 ;
#                 PNs_TDLIF:ulod_value = "N/A" ;
#         double ANs_TDLIF(POINTS);
#                 ANs_TDLIF:units = "pptv" ;
#                 ANs_TDLIF:standard_name = "ANs_TDLIF" ;
#                 ANs_TDLIF:missing_value = -999999 ;
#                 ANs_TDLIF:fill_value = -999999.0 ;
#                 ANs_TDLIF:scale = 1 ;
#                 ANs_TDLIF:llod_flag = -888888 ;
#                 ANs_TDLIF:llod_value = "N/A" ;
#                 ANs_TDLIF:ulod_flag = -777777 ;
#                 ANs_TDLIF:ulod_value = "N/A" ;
#         double HNO3_SAGA(POINTS);
#                 HNO3_SAGA:units = "pptv" ;
#                 HNO3_SAGA:standard_name = "HNO3_SAGA" ;
#                 HNO3_SAGA:missing_value = -999999 ;
#                 HNO3_SAGA:fill_value = -999999.0 ;
#                 HNO3_SAGA:scale = 1 ;
#                 HNO3_SAGA:llod_flag = -888888 ;
#                 HNO3_SAGA:llod_value = "N/A" ;
#                 HNO3_SAGA:ulod_flag = -777777 ;
#                 HNO3_SAGA:ulod_value = "N/A" ;
#         double Sulfate-lt-1um_MCIC_SAGA(POINTS);
#                 Sulfate-lt-1um_MCIC_SAGA:units = "ug std m-3" ;
#                 Sulfate-lt-1um_MCIC_SAGA:standard_name = "Sulfate-lt-1um_MCIC_SAGA" ;
#                 Sulfate-lt-1um_MCIC_SAGA:missing_value = -999999 ;
#                 Sulfate-lt-1um_MCIC_SAGA:fill_value = -999999.0 ;
#                 Sulfate-lt-1um_MCIC_SAGA:scale = 1 ;
#                 Sulfate-lt-1um_MCIC_SAGA:llod_flag = -888888 ;
#                 Sulfate-lt-1um_MCIC_SAGA:llod_value = "N/A" ;
#                 Sulfate-lt-1um_MCIC_SAGA:ulod_flag = -777777 ;
#                 Sulfate-lt-1um_MCIC_SAGA:ulod_value = "N/A" ;
#         double PAN_GTCIMS(POINTS);
#                 PAN_GTCIMS:units = "pptv" ;
#                 PAN_GTCIMS:standard_name = "PAN_GTCIMS" ;
#                 PAN_GTCIMS:missing_value = -999999 ;
#                 PAN_GTCIMS:fill_value = -999999.0 ;
#                 PAN_GTCIMS:scale = 1 ;
#                 PAN_GTCIMS:llod_flag = -888888 ;
#                 PAN_GTCIMS:llod_value = "N/A" ;
#                 PAN_GTCIMS:ulod_flag = -777777 ;
#                 PAN_GTCIMS:ulod_value = "N/A" ;
#         double PPN_GTCIMS(POINTS);
#                 PPN_GTCIMS:units = "pptv" ;
#                 PPN_GTCIMS:standard_name = "PPN_GTCIMS" ;
#                 PPN_GTCIMS:missing_value = -999999 ;
#                 PPN_GTCIMS:fill_value = -999999.0 ;
#                 PPN_GTCIMS:scale = 1 ;
#                 PPN_GTCIMS:llod_flag = -888888 ;
#                 PPN_GTCIMS:llod_value = "N/A" ;
#                 PPN_GTCIMS:ulod_flag = -777777 ;
#                 PPN_GTCIMS:ulod_value = "N/A" ;
#         double SO2_GTCIMS(POINTS);
#                 SO2_GTCIMS:units = "pptv" ;
#                 SO2_GTCIMS:standard_name = "SO2_GTCIMS" ;
#                 SO2_GTCIMS:missing_value = -999999 ;
#                 SO2_GTCIMS:fill_value = -999999.0 ;
#                 SO2_GTCIMS:scale = 1 ;
#                 SO2_GTCIMS:llod_flag = -888888 ;
#                 SO2_GTCIMS:llod_value = "N/A" ;
#                 SO2_GTCIMS:ulod_flag = -777777 ;
#                 SO2_GTCIMS:ulod_value = "N/A" ;
#         double HCl_GTCIMS(POINTS);
#                 HCl_GTCIMS:units = "pptv" ;
#                 HCl_GTCIMS:standard_name = "HCl_GTCIMS" ;
#                 HCl_GTCIMS:missing_value = -999999 ;
#                 HCl_GTCIMS:fill_value = -999999.0 ;
#                 HCl_GTCIMS:scale = 1 ;
#                 HCl_GTCIMS:llod_flag = -888888 ;
#                 HCl_GTCIMS:llod_value = "N/A" ;
#                 HCl_GTCIMS:ulod_flag = -777777 ;
#                 HCl_GTCIMS:ulod_value = "N/A" ;
#         double HNO4_GTCIMS(POINTS);
#                 HNO4_GTCIMS:units = "pptv" ;
#                 HNO4_GTCIMS:standard_name = "HNO4_GTCIMS" ;
#                 HNO4_GTCIMS:missing_value = -999999 ;
#                 HNO4_GTCIMS:fill_value = -999999.0 ;
#                 HNO4_GTCIMS:scale = 1 ;
#                 HNO4_GTCIMS:llod_flag = -888888 ;
#                 HNO4_GTCIMS:llod_value = "N/A" ;
#                 HNO4_GTCIMS:ulod_flag = -777777 ;
#                 HNO4_GTCIMS:ulod_value = "N/A" ;
#         double OH_HOx(POINTS);
#                 OH_HOx:units = "pptv" ;
#                 OH_HOx:standard_name = "OH_HOx" ;
#                 OH_HOx:missing_value = -999999 ;
#                 OH_HOx:fill_value = -999999.0 ;
#                 OH_HOx:scale = 1 ;
#                 OH_HOx:llod_flag = -888888 ;
#                 OH_HOx:llod_value = "N/A" ;
#                 OH_HOx:ulod_flag = -777777 ;
#                 OH_HOx:ulod_value = "N/A" ;
#         double HO2_HOx(POINTS);
#                 HO2_HOx:units = "pptv" ;
#                 HO2_HOx:standard_name = "HO2_HOx" ;
#                 HO2_HOx:missing_value = -999999 ;
#                 HO2_HOx:fill_value = -999999.0 ;
#                 HO2_HOx:scale = 1 ;
#                 HO2_HOx:llod_flag = -888888 ;
#                 HO2_HOx:llod_value = "N/A" ;
#                 HO2_HOx:ulod_flag = -777777 ;
#                 HO2_HOx:ulod_value = "N/A" ;
#         double OH_Reactivity(POINTS);
#                 OH_Reactivity:units = "s-1" ;
#                 OH_Reactivity:standard_name = "OH_Reactivity" ;
#                 OH_Reactivity:missing_value = -999999 ;
#                 OH_Reactivity:fill_value = -999999.0 ;
#                 OH_Reactivity:scale = 1 ;
#                 OH_Reactivity:llod_flag = -888888 ;
#                 OH_Reactivity:llod_value = "N/A" ;
#                 OH_Reactivity:ulod_flag = -777777 ;
#                 OH_Reactivity:ulod_value = "N/A" ;
#         double OH_Reactivity_TubeTemp(POINTS);
#                 OH_Reactivity_TubeTemp:units = "K" ;
#                 OH_Reactivity_TubeTemp:standard_name = "OH_Reactivity_TubeTemp" ;
#                 OH_Reactivity_TubeTemp:missing_value = -999999 ;
#                 OH_Reactivity_TubeTemp:fill_value = -999999.0 ;
#                 OH_Reactivity_TubeTemp:scale = 1 ;
#                 OH_Reactivity_TubeTemp:llod_flag = -888888 ;
#                 OH_Reactivity_TubeTemp:llod_value = "N/A" ;
#                 OH_Reactivity_TubeTemp:ulod_flag = -777777 ;
#                 OH_Reactivity_TubeTemp:ulod_value = "N/A" ;
#         double OH_Reactivity_TubePress(POINTS);
#                 OH_Reactivity_TubePress:units = "hPa" ;
#                 OH_Reactivity_TubePress:standard_name = "OH_Reactivity_TubePress" ;
#                 OH_Reactivity_TubePress:missing_value = -999999 ;
#                 OH_Reactivity_TubePress:fill_value = -999999.0 ;
#                 OH_Reactivity_TubePress:scale = 1 ;
#                 OH_Reactivity_TubePress:llod_flag = -888888 ;
#                 OH_Reactivity_TubePress:llod_value = "N/A" ;
#                 OH_Reactivity_TubePress:ulod_flag = -777777 ;
#                 OH_Reactivity_TubePress:ulod_value = "N/A" ;
#         double J[O3->O2+O(1D)](POINTS);
#                 J[O3->O2+O(1D)]:units = "s-1" ;
#                 J[O3->O2+O(1D)]:standard_name = "J[O3->O2+O(1D)]" ;
#                 J[O3->O2+O(1D)]:missing_value = -999999 ;
#                 J[O3->O2+O(1D)]:fill_value = -999999.0 ;
#                 J[O3->O2+O(1D)]:scale = 1 ;
#                 J[O3->O2+O(1D)]:llod_flag = -888888 ;
#                 J[O3->O2+O(1D)]:llod_value = "N/A" ;
#                 J[O3->O2+O(1D)]:ulod_flag = -777777 ;
#                 J[O3->O2+O(1D)]:ulod_value = "N/A" ;
#         double J[NO2->NO+O(3P)](POINTS);
#                 J[NO2->NO+O(3P)]:units = "s-1" ;
#                 J[NO2->NO+O(3P)]:standard_name = "J[NO2->NO+O(3P)]" ;
#                 J[NO2->NO+O(3P)]:missing_value = -999999 ;
#                 J[NO2->NO+O(3P)]:fill_value = -999999.0 ;
#                 J[NO2->NO+O(3P)]:scale = 1 ;
#                 J[NO2->NO+O(3P)]:llod_flag = -888888 ;
#                 J[NO2->NO+O(3P)]:llod_value = "N/A" ;
#                 J[NO2->NO+O(3P)]:ulod_flag = -777777 ;
#                 J[NO2->NO+O(3P)]:ulod_value = "N/A" ;
#         double J[N2O5->NO3+NO2](POINTS);
#                 J[N2O5->NO3+NO2]:units = "s-1" ;
#                 J[N2O5->NO3+NO2]:standard_name = "J[N2O5->NO3+NO2]" ;
#                 J[N2O5->NO3+NO2]:missing_value = -999999 ;
#                 J[N2O5->NO3+NO2]:fill_value = -999999.0 ;
#                 J[N2O5->NO3+NO2]:scale = 1 ;
#                 J[N2O5->NO3+NO2]:llod_flag = -888888 ;
#                 J[N2O5->NO3+NO2]:llod_value = "N/A" ;
#                 J[N2O5->NO3+NO2]:ulod_flag = -777777 ;
#                 J[N2O5->NO3+NO2]:ulod_value = "N/A" ;
#         double J[H2O2->2OH](POINTS);
#                 J[H2O2->2OH]:units = "s-1" ;
#                 J[H2O2->2OH]:standard_name = "J[H2O2->2OH]" ;
#                 J[H2O2->2OH]:missing_value = -999999 ;
#                 J[H2O2->2OH]:fill_value = -999999.0 ;
#                 J[H2O2->2OH]:scale = 1 ;
#                 J[H2O2->2OH]:llod_flag = -888888 ;
#                 J[H2O2->2OH]:llod_value = "N/A" ;
#                 J[H2O2->2OH]:ulod_flag = -777777 ;
#                 J[H2O2->2OH]:ulod_value = "N/A" ;
#         double J[HNO2->OH+NO](POINTS);
#                 J[HNO2->OH+NO]:units = "s-1" ;
#                 J[HNO2->OH+NO]:standard_name = "J[HNO2->OH+NO]" ;
#                 J[HNO2->OH+NO]:missing_value = -999999 ;
#                 J[HNO2->OH+NO]:fill_value = -999999.0 ;
#                 J[HNO2->OH+NO]:scale = 1 ;
#                 J[HNO2->OH+NO]:llod_flag = -888888 ;
#                 J[HNO2->OH+NO]:llod_value = "N/A" ;
#                 J[HNO2->OH+NO]:ulod_flag = -777777 ;
#                 J[HNO2->OH+NO]:ulod_value = "N/A" ;
#         double J[HNO3->OH+NO2](POINTS);
#                 J[HNO3->OH+NO2]:units = "s-1" ;
#                 J[HNO3->OH+NO2]:standard_name = "J[HNO3->OH+NO2]" ;
#                 J[HNO3->OH+NO2]:missing_value = -999999 ;
#                 J[HNO3->OH+NO2]:fill_value = -999999.0 ;
#                 J[HNO3->OH+NO2]:scale = 1 ;
#                 J[HNO3->OH+NO2]:llod_flag = -888888 ;
#                 J[HNO3->OH+NO2]:llod_value = "N/A" ;
#                 J[HNO3->OH+NO2]:ulod_flag = -777777 ;
#                 J[HNO3->OH+NO2]:ulod_value = "N/A" ;
#         double J[CH2O->H+HCO](POINTS);
#                 J[CH2O->H+HCO]:units = "s-1" ;
#                 J[CH2O->H+HCO]:standard_name = "J[CH2O->H+HCO]" ;
#                 J[CH2O->H+HCO]:missing_value = -999999 ;
#                 J[CH2O->H+HCO]:fill_value = -999999.0 ;
#                 J[CH2O->H+HCO]:scale = 1 ;
#                 J[CH2O->H+HCO]:llod_flag = -888888 ;
#                 J[CH2O->H+HCO]:llod_value = "N/A" ;
#                 J[CH2O->H+HCO]:ulod_flag = -777777 ;
#                 J[CH2O->H+HCO]:ulod_value = "N/A" ;
#         double J[CH2O->H2+CO](POINTS);
#                 J[CH2O->H2+CO]:units = "s-1" ;
#                 J[CH2O->H2+CO]:standard_name = "J[CH2O->H2+CO]" ;
#                 J[CH2O->H2+CO]:missing_value = -999999 ;
#                 J[CH2O->H2+CO]:fill_value = -999999.0 ;
#                 J[CH2O->H2+CO]:scale = 1 ;
#                 J[CH2O->H2+CO]:llod_flag = -888888 ;
#                 J[CH2O->H2+CO]:llod_value = "N/A" ;
#                 J[CH2O->H2+CO]:ulod_flag = -777777 ;
#                 J[CH2O->H2+CO]:ulod_value = "N/A" ;
#         double J[CH3CHO->CH3+HCO](POINTS);
#                 J[CH3CHO->CH3+HCO]:units = "s-1" ;
#                 J[CH3CHO->CH3+HCO]:standard_name = "J[CH3CHO->CH3+HCO]" ;
#                 J[CH3CHO->CH3+HCO]:missing_value = -999999 ;
#                 J[CH3CHO->CH3+HCO]:fill_value = -999999.0 ;
#                 J[CH3CHO->CH3+HCO]:scale = 1 ;
#                 J[CH3CHO->CH3+HCO]:llod_flag = -888888 ;
#                 J[CH3CHO->CH3+HCO]:llod_value = "N/A" ;
#                 J[CH3CHO->CH3+HCO]:ulod_flag = -777777 ;
#                 J[CH3CHO->CH3+HCO]:ulod_value = "N/A" ;
#         double J[C2H5CHO->C2H5+HCO](POINTS);
#                 J[C2H5CHO->C2H5+HCO]:units = "s-1" ;
#                 J[C2H5CHO->C2H5+HCO]:standard_name = "J[C2H5CHO->C2H5+HCO]" ;
#                 J[C2H5CHO->C2H5+HCO]:missing_value = -999999 ;
#                 J[C2H5CHO->C2H5+HCO]:fill_value = -999999.0 ;
#                 J[C2H5CHO->C2H5+HCO]:scale = 1 ;
#                 J[C2H5CHO->C2H5+HCO]:llod_flag = -888888 ;
#                 J[C2H5CHO->C2H5+HCO]:llod_value = "N/A" ;
#                 J[C2H5CHO->C2H5+HCO]:ulod_flag = -777777 ;
#                 J[C2H5CHO->C2H5+HCO]:ulod_value = "N/A" ;
#         double J[CHOCHO->CH2O+CO](POINTS);
#                 J[CHOCHO->CH2O+CO]:units = "s-1" ;
# ...
#                 n-Hexane_WAS:scale = 1 ;
#                 n-Hexane_WAS:llod_flag = -888888 ;
#                 n-Hexane_WAS:llod_value = "N/A" ;
#                 n-Hexane_WAS:ulod_flag = -777777 ;
#                 n-Hexane_WAS:ulod_value = "N/A" ;
#         double n-Heptane_WAS(POINTS);
#                 n-Heptane_WAS:units = "pptv" ;
#                 n-Heptane_WAS:standard_name = "n-Heptane_WAS" ;
#                 n-Heptane_WAS:missing_value = -999999 ;
#                 n-Heptane_WAS:fill_value = -999999.0 ;
#                 n-Heptane_WAS:scale = 1 ;
#                 n-Heptane_WAS:llod_flag = -888888 ;
#                 n-Heptane_WAS:llod_value = "N/A" ;
#                 n-Heptane_WAS:ulod_flag = -777777 ;
#                 n-Heptane_WAS:ulod_value = "N/A" ;
#         double Benzene_WAS(POINTS);
#                 Benzene_WAS:units = "pptv" ;
#                 Benzene_WAS:standard_name = "Benzene_WAS" ;
#                 Benzene_WAS:missing_value = -999999 ;
#                 Benzene_WAS:fill_value = -999999.0 ;
#                 Benzene_WAS:scale = 1 ;
#                 Benzene_WAS:llod_flag = -888888 ;
#                 Benzene_WAS:llod_value = "N/A" ;
#                 Benzene_WAS:ulod_flag = -777777 ;
#                 Benzene_WAS:ulod_value = "N/A" ;
#         double Toluene_WAS(POINTS);
#                 Toluene_WAS:units = "pptv" ;
#                 Toluene_WAS:standard_name = "Toluene_WAS" ;
#                 Toluene_WAS:missing_value = -999999 ;
#                 Toluene_WAS:fill_value = -999999.0 ;
#                 Toluene_WAS:scale = 1 ;
#                 Toluene_WAS:llod_flag = -888888 ;
#                 Toluene_WAS:llod_value = "N/A" ;
#                 Toluene_WAS:ulod_flag = -777777 ;
#                 Toluene_WAS:ulod_value = "N/A" ;
#         double Ethylbenzene_WAS(POINTS);
#                 Ethylbenzene_WAS:units = "pptv" ;
#                 Ethylbenzene_WAS:standard_name = "Ethylbenzene_WAS" ;
#                 Ethylbenzene_WAS:missing_value = -999999 ;
#                 Ethylbenzene_WAS:fill_value = -999999.0 ;
#                 Ethylbenzene_WAS:scale = 1 ;
#                 Ethylbenzene_WAS:llod_flag = -888888 ;
#                 Ethylbenzene_WAS:llod_value = "N/A" ;
#                 Ethylbenzene_WAS:ulod_flag = -777777 ;
#                 Ethylbenzene_WAS:ulod_value = "N/A" ;
#         double m+p-Xylene_WAS(POINTS);
#                 m+p-Xylene_WAS:units = "pptv" ;
#                 m+p-Xylene_WAS:standard_name = "m+p-Xylene_WAS" ;
#                 m+p-Xylene_WAS:missing_value = -999999 ;
#                 m+p-Xylene_WAS:fill_value = -999999.0 ;
#                 m+p-Xylene_WAS:scale = 1 ;
#                 m+p-Xylene_WAS:llod_flag = -888888 ;
#                 m+p-Xylene_WAS:llod_value = "N/A" ;
#                 m+p-Xylene_WAS:ulod_flag = -777777 ;
#                 m+p-Xylene_WAS:ulod_value = "N/A" ;
#         double o-Xylene_WAS(POINTS);
#                 o-Xylene_WAS:units = "pptv" ;
#                 o-Xylene_WAS:standard_name = "o-Xylene_WAS" ;
#                 o-Xylene_WAS:missing_value = -999999 ;
#                 o-Xylene_WAS:fill_value = -999999.0 ;
#                 o-Xylene_WAS:scale = 1 ;
#                 o-Xylene_WAS:llod_flag = -888888 ;
#                 o-Xylene_WAS:llod_value = "N/A" ;
#                 o-Xylene_WAS:ulod_flag = -777777 ;
#                 o-Xylene_WAS:ulod_value = "N/A" ;
#         double alpha-Pinene_WAS(POINTS);
#                 alpha-Pinene_WAS:units = "pptv" ;
#                 alpha-Pinene_WAS:standard_name = "alpha-Pinene_WAS" ;
#                 alpha-Pinene_WAS:missing_value = -999999 ;
#                 alpha-Pinene_WAS:fill_value = -999999.0 ;
#                 alpha-Pinene_WAS:scale = 1 ;
#                 alpha-Pinene_WAS:llod_flag = -888888 ;
#                 alpha-Pinene_WAS:llod_value = "N/A" ;
#                 alpha-Pinene_WAS:ulod_flag = -777777 ;
#                 alpha-Pinene_WAS:ulod_value = "N/A" ;
#         double beta-Pinene_WAS(POINTS);
#                 beta-Pinene_WAS:units = "pptv" ;
#                 beta-Pinene_WAS:standard_name = "beta-Pinene_WAS" ;
#                 beta-Pinene_WAS:missing_value = -999999 ;
#                 beta-Pinene_WAS:fill_value = -999999.0 ;
#                 beta-Pinene_WAS:scale = 1 ;
#                 beta-Pinene_WAS:llod_flag = -888888 ;
#                 beta-Pinene_WAS:llod_value = "N/A" ;
#                 beta-Pinene_WAS:ulod_flag = -777777 ;
#                 beta-Pinene_WAS:ulod_value = "N/A" ;
#         double DN_IR_Irrad(POINTS);
#                 DN_IR_Irrad:units = "W m-2" ;
#                 DN_IR_Irrad:standard_name = "DN_IR_Irrad" ;
#                 DN_IR_Irrad:missing_value = -999999 ;
#                 DN_IR_Irrad:fill_value = -999999.0 ;
#                 DN_IR_Irrad:scale = 1 ;
#                 DN_IR_Irrad:llod_flag = -888888 ;
#                 DN_IR_Irrad:llod_value = "N/A" ;
#                 DN_IR_Irrad:ulod_flag = -777777 ;
#                 DN_IR_Irrad:ulod_value = "N/A" ;
#         double UP_IR_Irrad(POINTS);
#                 UP_IR_Irrad:units = "W m-2" ;
#                 UP_IR_Irrad:standard_name = "UP_IR_Irrad" ;
#                 UP_IR_Irrad:missing_value = -999999 ;
#                 UP_IR_Irrad:fill_value = -999999.0 ;
#                 UP_IR_Irrad:scale = 1 ;
#                 UP_IR_Irrad:llod_flag = -888888 ;
#                 UP_IR_Irrad:llod_value = "N/A" ;
#                 UP_IR_Irrad:ulod_flag = -777777 ;
#                 UP_IR_Irrad:ulod_value = "N/A" ;
#         double DN_Solar_Irrad(POINTS);
#                 DN_Solar_Irrad:units = "W m-2" ;
#                 DN_Solar_Irrad:standard_name = "DN_Solar_Irrad" ;
#                 DN_Solar_Irrad:missing_value = -999999 ;
#                 DN_Solar_Irrad:fill_value = -999999.0 ;
#                 DN_Solar_Irrad:scale = 1 ;
#                 DN_Solar_Irrad:llod_flag = -888888 ;
#                 DN_Solar_Irrad:llod_value = "N/A" ;
#                 DN_Solar_Irrad:ulod_flag = -777777 ;
#                 DN_Solar_Irrad:ulod_value = "N/A" ;
#         double UP_Solar_Irrad(POINTS);
#                 UP_Solar_Irrad:units = "W m-2" ;
#                 UP_Solar_Irrad:standard_name = "UP_Solar_Irrad" ;
#                 UP_Solar_Irrad:missing_value = -999999 ;
#                 UP_Solar_Irrad:fill_value = -999999.0 ;
#                 UP_Solar_Irrad:scale = 1 ;
#                 UP_Solar_Irrad:llod_flag = -888888 ;
#                 UP_Solar_Irrad:llod_value = "N/A" ;
#                 UP_Solar_Irrad:ulod_flag = -777777 ;
#                 UP_Solar_Irrad:ulod_value = "N/A" ;
#         double DN500nm_SSFR(POINTS);
#                 DN500nm_SSFR:units = "W m-2 nm-1" ;
#                 DN500nm_SSFR:standard_name = "DN500nm_SSFR" ;
#                 DN500nm_SSFR:missing_value = -999999 ;
#                 DN500nm_SSFR:fill_value = -999999.0 ;
#                 DN500nm_SSFR:scale = 1 ;
#                 DN500nm_SSFR:llod_flag = -888888 ;
#                 DN500nm_SSFR:llod_value = "N/A" ;
#                 DN500nm_SSFR:ulod_flag = -777777 ;
#                 DN500nm_SSFR:ulod_value = "N/A" ;
#         double DN650nm_SSFR(POINTS);
#                 DN650nm_SSFR:units = "W m-2 nm-1" ;
#                 DN650nm_SSFR:standard_name = "DN650nm_SSFR" ;
#                 DN650nm_SSFR:missing_value = -999999 ;
#                 DN650nm_SSFR:fill_value = -999999.0 ;
#                 DN650nm_SSFR:scale = 1 ;
#                 DN650nm_SSFR:llod_flag = -888888 ;
#                 DN650nm_SSFR:llod_value = "N/A" ;
#                 DN650nm_SSFR:ulod_flag = -777777 ;
#                 DN650nm_SSFR:ulod_value = "N/A" ;
#         double DN936nm_SSFR(POINTS);
#                 DN936nm_SSFR:units = "W m-2 nm-1" ;
#                 DN936nm_SSFR:standard_name = "DN936nm_SSFR" ;
#                 DN936nm_SSFR:missing_value = -999999 ;
#                 DN936nm_SSFR:fill_value = -999999.0 ;
#                 DN936nm_SSFR:scale = 1 ;
#                 DN936nm_SSFR:llod_flag = -888888 ;
#                 DN936nm_SSFR:llod_value = "N/A" ;
#                 DN936nm_SSFR:ulod_flag = -777777 ;
#                 DN936nm_SSFR:ulod_value = "N/A" ;
#         double DN1600nm_SSFR(POINTS);
#                 DN1600nm_SSFR:units = "W m-2 nm-1" ;
#                 DN1600nm_SSFR:standard_name = "DN1600nm_SSFR" ;
#                 DN1600nm_SSFR:missing_value = -999999 ;
#                 DN1600nm_SSFR:fill_value = -999999.0 ;
#                 DN1600nm_SSFR:scale = 1 ;
#                 DN1600nm_SSFR:llod_flag = -888888 ;
#                 DN1600nm_SSFR:llod_value = "N/A" ;
#                 DN1600nm_SSFR:ulod_flag = -777777 ;
#                 DN1600nm_SSFR:ulod_value = "N/A" ;
#         double DN350to700nm_SSFR(POINTS);
#                 DN350to700nm_SSFR:units = "W m-2" ;
#                 DN350to700nm_SSFR:standard_name = "DN350to700nm_SSFR" ;
#                 DN350to700nm_SSFR:missing_value = -999999 ;
#                 DN350to700nm_SSFR:fill_value = -999999.0 ;
#                 DN350to700nm_SSFR:scale = 1 ;
#                 DN350to700nm_SSFR:llod_flag = -888888 ;
#                 DN350to700nm_SSFR:llod_value = "N/A" ;
#                 DN350to700nm_SSFR:ulod_flag = -777777 ;
#                 DN350to700nm_SSFR:ulod_value = "N/A" ;
#         double DN350to2150nm_SSFR(POINTS);
#                 DN350to2150nm_SSFR:units = "W m-2" ;
#                 DN350to2150nm_SSFR:standard_name = "DN350to2150nm_SSFR" ;
#                 DN350to2150nm_SSFR:missing_value = -999999 ;
#                 DN350to2150nm_SSFR:fill_value = -999999.0 ;
#                 DN350to2150nm_SSFR:scale = 1 ;
#                 DN350to2150nm_SSFR:llod_flag = -888888 ;
#                 DN350to2150nm_SSFR:llod_value = "N/A" ;
#                 DN350to2150nm_SSFR:ulod_flag = -777777 ;
#                 DN350to2150nm_SSFR:ulod_value = "N/A" ;
#         double UP500nm_SSFR(POINTS);
#                 UP500nm_SSFR:units = "W m-2 nm-1" ;
#                 UP500nm_SSFR:standard_name = "UP500nm_SSFR" ;
#                 UP500nm_SSFR:missing_value = -999999 ;
#                 UP500nm_SSFR:fill_value = -999999.0 ;
#                 UP500nm_SSFR:scale = 1 ;
#                 UP500nm_SSFR:llod_flag = -888888 ;
#                 UP500nm_SSFR:llod_value = "N/A" ;
#                 UP500nm_SSFR:ulod_flag = -777777 ;
#                 UP500nm_SSFR:ulod_value = "N/A" ;
#         double UP650nm_SSFR(POINTS);
#                 UP650nm_SSFR:units = "W m-2 nm-1" ;
#                 UP650nm_SSFR:standard_name = "UP650nm_SSFR" ;
#                 UP650nm_SSFR:missing_value = -999999 ;
#                 UP650nm_SSFR:fill_value = -999999.0 ;
#                 UP650nm_SSFR:scale = 1 ;
#                 UP650nm_SSFR:llod_flag = -888888 ;
#                 UP650nm_SSFR:llod_value = "N/A" ;
#                 UP650nm_SSFR:ulod_flag = -777777 ;
#                 UP650nm_SSFR:ulod_value = "N/A" ;
#         double UP936nm_SSFR(POINTS);
#                 UP936nm_SSFR:units = "W m-2 nm-1" ;
#                 UP936nm_SSFR:standard_name = "UP936nm_SSFR" ;
#                 UP936nm_SSFR:missing_value = -999999 ;
#                 UP936nm_SSFR:fill_value = -999999.0 ;
#                 UP936nm_SSFR:scale = 1 ;
#                 UP936nm_SSFR:llod_flag = -888888 ;
#                 UP936nm_SSFR:llod_value = "N/A" ;
#                 UP936nm_SSFR:ulod_flag = -777777 ;
#                 UP936nm_SSFR:ulod_value = "N/A" ;
#         double UP1600nm_SSFR(POINTS);
#                 UP1600nm_SSFR:units = "W m-2 nm-1" ;
#                 UP1600nm_SSFR:standard_name = "UP1600nm_SSFR" ;
#                 UP1600nm_SSFR:missing_value = -999999 ;
#                 UP1600nm_SSFR:fill_value = -999999.0 ;
#                 UP1600nm_SSFR:scale = 1 ;
#                 UP1600nm_SSFR:llod_flag = -888888 ;
#                 UP1600nm_SSFR:llod_value = "N/A" ;
#                 UP1600nm_SSFR:ulod_flag = -777777 ;
#                 UP1600nm_SSFR:ulod_value = "N/A" ;
#         double UP350to700nm_SSFR(POINTS);
#                 UP350to700nm_SSFR:units = "W m-2" ;
#                 UP350to700nm_SSFR:standard_name = "UP350to700nm_SSFR" ;
#                 UP350to700nm_SSFR:missing_value = -999999 ;
#                 UP350to700nm_SSFR:fill_value = -999999.0 ;
#                 UP350to700nm_SSFR:scale = 1 ;
#                 UP350to700nm_SSFR:llod_flag = -888888 ;
#                 UP350to700nm_SSFR:llod_value = "N/A" ;
#                 UP350to700nm_SSFR:ulod_flag = -777777 ;
#                 UP350to700nm_SSFR:ulod_value = "N/A" ;
#         double UP350to2150nm_SSFR(POINTS);
#                 UP350to2150nm_SSFR:units = "W m-2" ;
#                 UP350to2150nm_SSFR:standard_name = "UP350to2150nm_SSFR" ;
#                 UP350to2150nm_SSFR:missing_value = -999999 ;
#                 UP350to2150nm_SSFR:fill_value = -999999.0 ;
#                 UP350to2150nm_SSFR:scale = 1 ;
#                 UP350to2150nm_SSFR:llod_flag = -888888 ;
#                 UP350to2150nm_SSFR:llod_value = "N/A" ;
#                 UP350to2150nm_SSFR:ulod_flag = -777777 ;
#                 UP350to2150nm_SSFR:ulod_value = "N/A" ;
#         double CloudIndicator(POINTS);
#                 CloudIndicator:units = "none" ;
#                 CloudIndicator:standard_name = "CloudIndicator" ;
#                 CloudIndicator:missing_value = -999999 ;
#                 CloudIndicator:fill_value = -999999.0 ;
#                 CloudIndicator:scale = 1 ;
#                 CloudIndicator:llod_flag = -888888 ;
#                 CloudIndicator:llod_value = "N/A" ;
#                 CloudIndicator:ulod_flag = -777777 ;
#                 CloudIndicator:ulod_value = "N/A" ;
#
#
# // global properties:
#                 :fmt = "1001" ;
#                 :n_header_lines = 409 ;
#                 :PI_NAME = "Shook, Michael" ;
#                 :ORGANIZATION_NAME = "NASA Atmospheric Composition Branch, NASA Langley Research Center (SSAI)" ;
#                 :SOURCE_DESCRIPTION = "Merged data file for DC3, Flights 01-18 (20120518-20120622), on the DC-8 platform. Data is merged to 60 seconds/timeline." ;
#                 :MISSION_NAME = "NSF DC3 Mission 2012" ;
#                 :VOLUME_INFO = "1, 1" ;
#                 :SDATE = "20120518" ;
#                 :WDATE = "20160113" ;
#                 :TIME_INTERVAL = "-1" ;
#                 :INDEPENDENT_VARIABLE = "Fractional_Day, none" ;
#                 :PI_CONTACT_INFO = "michael.shook@nasa.gov,jennifer.r.olson@nasa.gov,gao.chen@nasa.gov" ;
#                 :PLATFORM = "NASA Dryden DC-8 Aircraft" ;
#                 :LOCATION = "Latitude, Longitude, and Altitude included in data records" ;
#                 :ASSOCIATED_DATA = "N/A" ;
#                 :INSTRUMENT_INFO = "N/A" ;
#                 :DATA_INFO = "Please see PI data file for explanation of ULOD and LLOD." ;
#                 :UNCERTAINTY = "See individual files for uncertainty information." ;
#                 :ULOD_FLAG = "-777777" ;
#                 :ULOD_VALUE = "N/A" ;
#                 :LLOD_FLAG = "-888888" ;
#                 :LLOD_VALUE = "N/A" ;
#                 :DM_CONTACT_INFO = "gao.chen@nasa.gov" ;
#                 :PROJECT_INFO = "N/A" ;
#                 :STIPULATIONS_ON_USE = "N/A" ;
#                 :OTHER_COMMENTS = "This merge was created using data in the NASA DC3 archive as of 01/12/2016.\n In most cases, variable names have been kept identical\n to those submitted in the raw data files.\n However, in some cases, names have been changed \n (e.g., to eliminate duplication) \n Units have been standardized throughout the merge.\n Contact michael.shook@nasa.gov with any questions as to which data was included.\n" ;
#                 :REVISION = "R7" ;
#                 :R7 = "Includes data submitted as of 01/12/2016. See the readme file for a more detailed changelog." ;
#                 :R6 = "Includes data submitted as of 05/19/2015." ;
#                 :R5 = "Includes data submitted as of 06/09/2014." ;
#                 :R4 = "Includes data submitted as of 03/03/2014." ;
#                 :R3 = "Includes data submitted as of 11/26/2013." ;
#                 :R2 = "Includes data submitted as of 11/25/2013." ;
#                 :R1 = "Includes data submitted as of 03/26/2013." ;
#                 :R0 = "Includes data submitted as of 02/05/2013." ;
#                 :TFLAG = "Fractional_Day" ;
#                 :history = "icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict;dump --header --format=ffi1001 icartt/dc3-mrg60-dc8_merge_20120518_R7_thru20120622.ict;" ;
# }

# %% [markdown]
# # CHECK POINT
#
# 1. List 5 attributes of the file
#
#     -
#
# 2. Modify the command above to extract only the O3_ESRL variable.
#
#     -
#
# 3. What attributes does O3_ESRL have?
#
#     -

# %% [markdown]
# # Answers Hidden
# <div class="answers">
# 1. global properties
#   * fmt = "1001" ;
#   * n_header_lines = 409
#   * PI_NAME = "Shook, Michael"
#   * ORGANIZATION_NAME = "NASA Atmospheric Composition Branch, NASA Langley Research Center (SSAI)"
#   * SOURCE_DESCRIPTION = "Merged data file for DC3, Flights 01-18 (20120518-20120622), on the DC-8 platform. Data is merged to 60 seconds/timeline."
#
# 2.
# ```
# dc3args = PNC('dump', '--header',
#               '--variables=O3_ESRL',
#               '--format=ffi1001', dc3path,
#               actions = True)
# ```
#   * scale = 1 ;
#   * ulod_flag = -777777 ;
#   * units = "ppbv" ;
#   * fill_value = -999999.0 ;
#   * llod_flag = -888888 ;
#   * missing_value = -999999 ;
#   * standard_name = "O3_ESRL" ;
#   * ulod_value = "N/A" ;
#   * llod_value = "N/A" ;
# </div>

# %% [markdown]
# # Common Processing and Terminology
#
# This section will explain many of the techniques used in the tile plot section and in all subsequent sections.
#
# 1. slicing in numpy
# 2. dimensional reductions
# 3. Loading data from different formats
#   * CMAQ (already done)
#   * CAMx, WRF, GEOS-Chem, CSV, NASA AMES, AQS
# 4. Adding coordinate variables
# 5. Using named dimensions via PseudoNetCDF
# 6. Adding derived variables via PseudoNetCDF

# %% [markdown]
# # Slicing and Aggregating

# %%
# Load file (no extra processing or actions)
dc3args = PNC('--format=ffi1001', dc3path)
dc3file = dc3args.ifiles[0]

# Get a variable
O3_ESRL = dc3file.variables['O3_ESRL']

# Slice (start:stop:step)
O3_subset = O3_ESRL[1:100:10]

# Mean of slice
O3_subset_mean = O3_subset.mean()
print(O3_subset_mean)
# Out:
# 73.782911928

# %% [markdown]
# # Check Point
#
# - Describe the elements selected based on the slice.
# - What dimension was averaged?

# %% [markdown]
# # Answers Hidden
#
# <div class="answers">
# - Start with the second element, include up to the 200th element; of that set, start with the first and select every 10th afer that.
# - Use help(O3_subset.mean) to learn that mean applies to all dimensions unless specified.
# - In this case, it is applied to POINTS. We know because there is only one.
# </div>

# %% [markdown]
# # PNC
#
# - uses named dimensions
# - adjusts dimensions

# %%
# Repeat, but apply same processing to all variables
dc3procargs = PNC('--format=ffi1001', '--slice=POINTS,1,100,10', '--reduce=POINTS,mean', dc3path)
dc3file = dc3procargs.ifiles[0]
O3_pnc_subset_mean = dc3file.variables['O3_ESRL']

# %%
print(O3_pnc_subset_mean)
# Out:
#     double O3_ESRL(POINTS); // shape: (1,)
#         O3_ESRL:scale = 1 ;
#         O3_ESRL:missing_value = -999999 ;
#         O3_ESRL:ulod_flag = -777777 ;
#         O3_ESRL:units = "ppbv" ;
#         O3_ESRL:fill_value = -999999.0 ;
#         O3_ESRL:llod_value = "N/A" ;
#         O3_ESRL:llod_flag = -888888 ;
#         O3_ESRL:ulod_value = "N/A" ;
#         O3_ESRL:standard_name = "O3_ESRL" ;
# array: [73.782911928]

# %% [markdown]
# # Exercise
#
# 1. Describe the coordinates of both files.
# 2. Start with the DC3 data
# 3. Then, use the CMAQ data
#
# Goals: familiarity with coordinates, combining files, using convolutions, adding derived variables.

# %% [markdown]
# # CHECK POINT 2:
#
# What are the dimensions in the DC3 file?
#
# List 4 "coordinate" variable names and units that can be used to answer area  of interest
#
# 1. _
# 2. _
# 3. _
# 4. _

# %% [markdown]
# # ANSWERS Hidden
#
# <div class="answers">
#
# - Dimensions = POINTS
# - Variables:
#   - LATITUDE,degs
#   - LONGITUDE,degs
#   - PRESSURE,hPa
#   - Fractional_Day,none = by convention days since 2004-12-31
#
# </div>

# %% [markdown]
# # Get the range of values (min, median, max) for each variable

# %%
from PseudoNetCDF import PNC
dc3args = PNC("--format=ffi1001",
           "--variables=Fractional_Day,LATITUDE,LONGITUDE,PRESSURE",
           dc3path)

# %% [markdown]
# # CHECK POINT 3:
# What are the minimum, mean, and maximum values for each variable?
#
# * _
# * _
# * _
# * _

# %% [markdown]
# # ANSWERS Hidden
#
# <div class="answers">
# For POINTS,100,200
# ```
# for varkey in dc3args.variables:
#     print(varkey, dc3file.variables[varkey].min(), dc3file.variables[varkey].mean(), dc3file.variables[varkey].max())
# ```
#
# - Fractional_Day 139.86354 139.8979167 139.93229
# - LATITUDE 40.27951427 41.1336588365 42.14375258
# - LONGITUDE 255.4862488 256.739798669 258.6718221
# - PRESSURE 519.8900667 583.703467165 693.8251833
# </div>

# %% [markdown]
# # Now we'll work with CMAQ

# %% [markdown]
# CHECK POINT:
# What are the relevant dimensions in CMAQ?
#
# 1. _
# 2. _
# 3. _
# 4. _

# %% [markdown]
# # ANSWERS Hidden
#
# <div class="answers">
# ```
# from PseudoNetCDF import PNC
# args = PNC(aconcpath)
# cmaqfile = args.ifiles[0]
# print(cmaqfile.dimensions.keys())
# ```
#
# - TSTEP
# - LAY
# - ROW
# - COL
#
# </div>

# %% [markdown]
# # What are the Latitude/Longitude Coordinates?
#
# Many applications of CMAQ use Lambert Conformal Conic or another projected coordinate system. This can make comparing with geographic coordinates difficult.
#
# PNC offers helper tools to convert x/y to lat/lon (uses the IOAPI_ISPH environmental variable).
#
# Try running the command below:
# 1. *without* and then,
# 2. with the "--from-conv=ioapi" option.

# %%
from PseudoNetCDF import PNC
args = PNC(aconcpath)
cmaqfile = args.ifiles[0]
print(cmaqfile.variables.keys())
args = PNC("--from-conv=ioapi", aconcpath)
cmaqfile = args.ifiles[0]
print(cmaqfile.variables.keys())
# Out:
# odict_keys(['TFLAG', 'O3', 'NO', 'CO', 'NO2', 'ASO4I', 'ASO4J', 'NH3'])
# odict_keys(['ASO4J', 'NO2', 'TFLAG', 'ASO4I', 'CO', 'NH3', 'NO', 'O3', 'layer', 'level', 'time', 'time_bounds', 'LambertConformalProjection', 'x', 'y', 'latitude', 'longitude', 'latitude_bounds', 'longitude_bounds'])

# %% [markdown]
# # CHECK POINT
#
# What are the relevant coordinate variables in CMAQ? With and without conventions?
#
# 1. _
# 2. _
# 3. _
# 4. _
#
# What is missing?

# %% [markdown]
# # ANSWERS Hidden
#
# <div class="answers">
#
# - time,TFLAG
# - layer,N/A
# - latitude,N/A
# - longitude,N/A
#
# - missing: pressure
# </div>

# %% [markdown]
# ## What is vertical layer coordinate variable
#
# WRF CMAQ applications use the hydrostatic pressure coordinate system ($\eta$).
#
# $\eta = \frac{P - P_{top}}{P_{surf} - P_{top}}$ = any3dfile.VGLVLS
#
# $P = \eta (P_{surf} - P_{top}) + P_{top} \approx $ `METCRO3D.variables['PRES']`
#
# $P_{top}$ = `any3dfile.VGTOP`; $P_{surf}$ = `METCRO2D.variables['PRSFC']`

# %% [markdown]
# ## Big approximation
# In flat and low terrain, set $P_{surf}$ = 101325
# ```
# --expr=PRES=O3*0.+np.convolve(ifile.VGLVLS[:],[0.5,.5])[None,:,None,None]*(101325.-ifile.VGTOP)+ifile.VGTOP;PRES.units='Pa'
# ```

# %% [markdown]
# ### Combining files to get pressure
#
# Here we make one file from two. We get PRES from METCRO3D.

# %%
from PseudoNetCDF import PNC

args = PNC("--merge", "--",\
           "--from-conv=ioapi", aconcpath,\
           "--sep", "--variables=PRES", "--convolve=TSTEP,valid,.5,.5", metcro3dpath)
aconcfile = args.ifiles[0]
time = aconcfile.variables['time']
lat = aconcfile.variables['latitude']
lon = aconcfile.variables['longitude']
pres = aconcfile.variables['PRES']

# %% [markdown]
# #### CHECK POINT:
#
# The "--" forces commands to be solved in order. What do the remaining options do?
#
# --sep =
#
# --variables =
#
# --convolve =

# %% [markdown]
# # ANSWERS HIDDEN
# <div class="answers">
#
# ```
# --sep = separates groups of commands so that they only apply to a group of files
#
# --variables = subsets the variables in each file
#
# --convolve = applies a convolute on a dimension (TSTEP) using a mode (valid) and a sequence of weighting factors.
# ```
# </div>

# %% [markdown]
# ## Check Point: What are the range of all coordinate variables?
#
# Amswers Hidden.
# <div class="answers">
# ```
# for varkey in 'latitude longitude PRES time'.split():
#     cvar = aconcfile.variables[varkey]
#     print(cvar.units, np.percentile(cvar[:], [0, 50, 100]))
# ```
# </div>

# %% [markdown]
# Optionally, use the PNC('dump', '--help') option `pncdump.py -h` and describe what these options do.
#
# - -t, --timestring
# - --full-indices=c
# - --full-indices=f

# %%
PNC('dump', '--help', actions = True);
# Out:
# usage: PNC dump [-H] [-t] [--full-indices [c|f]] [-l LEN]
#                 [--float-precision FDIG] [--double-precision PDIG]
#                 [--dump-name CDLNAME] [--verbose] [--help] [--pnc PNC]
#                 [-f {see --list-formats for choices}] [--list-formats]
#                 [--help-format HELPFORMAT] [--sep] [--inherit] [--mangle]
#                 [--rename RENAME] [--remove-singleton REMOVESINGLETON]
#                 [--coordkeys key1,key2] [-v varname1[,varname2[,...,varnameN]]
#                 [-a att_nm,var_nm,mode,att_typ,att_val] [-m MASKS]
#                 [--from-convention FROMCONV] [--to-convention TOCONV]
#                 [--stack STACK] [--merge] [-s dim,start[,stop[,step]]]
#                 [-r dim,function[,weight]] [--mesh dim,weight,function]
#                 [-c dim,mode,wgt1,wgt2,...wgtN] [-e EXTRACT]
#                 [--extract-file EXTRACTFILE]
#                 [--extractmethod {nn,linear,cubic,quintic,KDTree}]
#                 [--op-typ OPERATORS] [--expr EXPRESSIONS]
#                 [--exprscript EXPRESSIONSCRIPTS]
#                 [ifiles [ifiles ...]]
#
# Output Common Data Language (like from ncdump)
#
# positional arguments:
#   ifiles                path to a file formatted as type -f
#
# optional arguments:
#   -H, --header
#   -t, --timestring
#   --full-indices [c|f]  Provide indices in CDL using either C or Fortran style
#                         indexes. C style is 0-based and ordered from slowest
#                         iterating dimension to fastest. Fortran style is
#                         1-based and ordered from fastest to slowest iterating
#                         dimension
#   -l LEN, --length LEN  CDL line length (pncdump only)
#   --float-precision FDIG
#                         single precision digitis (default 8; pncdump only)
#   --double-precision PDIG
#                         pdig double precision digits (default 16; pncdump
#                         only)
#   --dump-name CDLNAME   Name for display in ncdump
#   --verbose             Provides verbosity with pncgen
#   --help                Displays help
#   --pnc PNC             Set of pseudonetcdf commands to be process separately
#   -f {see --list-formats for choices}, --format {see --list-formats for choices}
#                         File format (default netcdf), can be one of the
#                         choices listed, or an expression that evaluates to a
#                         reader. Keyword arguments are passed via ,kwd=value.
#   --list-formats        Show format options for -f
#   --help-format HELPFORMAT
#                         Show help for file format (must be one of the options
#                         for -f)
#   --sep                 Used to separate groups of arguments for parsing
#                         (e.g., pncgen -- [options1] file(s)1 [--sep [options2]
#                         file(s)2 [... [--sep [optionsN] file(s)N]]
#   --inherit             Allow subparsed sections (separated with -- and --sep)
#                         to inherit from global options (-f, --format is always
#                         inherited).
#   --mangle              Remove non-standard ascii from names
#   --rename RENAME       Provide pairs of strings to be substituted
#                         --rename=type,oldkey,newkey (type: v = variable; d =
#                         dimension;)
#   --remove-singleton REMOVESINGLETON
#                         Remove singleton (length 1) dimensions
#   --coordkeys key1,key2
#                         Variables to be ignored in pncbo.
#   -v varname1[,varname2[,...,varnameN], --variables varname1[,varname2[,...,varnameN]
#                         Variable names or regular expressions (using match)
#                         separated by ','. If a group(s) has been specified,
#                         only variables in that (those) group(s) will be
#                         selected.
#   -a att_nm,var_nm,mode,att_typ,att_val, --attribute att_nm,var_nm,mode,att_typ,att_val
#                         Variables have attributes that can be added following
#                         nco syntax (--attribute
#                         att_nm,var_nm,mode,att_typ,att_val); mode = a,c,d,m,o
#                         and att_typ = f,d,l,s,c,b; att_typ is any valid numpy
#                         type.
#   -m MASKS, --mask MASKS
#                         Masks to apply (e.g., greater,0 or less,0 or values,0,
#                         or where,(time[:]%24<12)[:,None].repeat(10,1))
#   --from-convention FROMCONV
#                         From convention currently only support ioapi
#   --to-convention TOCONV
#                         To convention currently only supports cf
#   --stack STACK         Concatentate (stack) files on the dimension.
#   --merge               Combine variables into one file
#   -s dim,start[,stop[,step]], --slice dim,start[,stop[,step]]
#                         Variables have dimensions (time, layer, lat, lon),
#                         which can be subset using dim,start,stop,stride (e.g.,
#                         --slice=layer,0,47,5 would sample every fifth layer
#                         starting at 0)
#   -r dim,function[,weight], --reduce dim,function[,weight]
#                         Variable dimensions can be reduced using
#                         dim,function,weight syntax (e.g.,
#                         --reduce=layer,mean,weight). Weighting is not fully
#                         functional.
#   --mesh dim,weight,function
#                         Variable dimensions can be meshed using
#                         dim,function,weight syntax (e.g.,
#                         --mesh=time,0.5,mean).
#   -c dim,mode,wgt1,wgt2,...wgtN, --convolve dim,mode,wgt1,wgt2,...wgtN
#                         Variable dimension is reduced by convolve function
#                         (dim,mode,wgt1,wgt2,...wgtN)
#   -e EXTRACT, --extract EXTRACT
#                         lon/lat coordinates to extract
#                         lon1,lat1/lon2,lat2/lon3,lat3/.../lonN,latN
#   --extract-file EXTRACTFILE
#                         pncparse options for file
#   --extractmethod {nn,linear,cubic,quintic,KDTree}
#                         Method for extraction
#   --op-typ OPERATORS    Operator for binary file operations. Binary file
#                         operations use the first two files, then the result
#                         and the next file, etc. Use // or <= or % or is not or
#                         >> or & or == or != or + or * or - or / or < or >= or
#                         ** or > or << or | or is or ^
#   --expr EXPRESSIONS    Generic expressions to execute in the context of the
#                         file.
#   --exprscript EXPRESSIONSCRIPTS
#                         Generic expressions to execute in the context of the
#                         file.
#
# *ifile or pnc are required
